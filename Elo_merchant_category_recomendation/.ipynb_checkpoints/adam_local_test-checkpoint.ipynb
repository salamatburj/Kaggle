# %%
import numpy as np
import lightgbm as lgb
import pickle
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, roc_curve, mean_squared_error

# %%
train = pd.read_pickle('df_train.pickle')
test = pd.read_pickle('df_test.pickle')

target = np.loadtxt('wang.target.txt')
outlier = np.zeros(len(target), dtype=np.int)
outlier[target < -33] = 1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\io\pickle.py in try_read(path, encoding)
#      98         try:
# ---> 99             return read_wrapper(lambda f: pkl.load(f))
#     100         except Exception:
#
# ~\Anaconda3\lib\site-packages\pandas\io\pickle.py in read_wrapper(func)
#      81                             compression=inferred_compression,
# ---> 82                             is_text=False)
#      83         try:
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     395             # Python 3 and binary mode
# --> 396             f = open(path_or_buf, mode)
#     397         handles.append(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'df_train.pickle'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\io\pickle.py in try_read(path, encoding)
#     103                 return read_wrapper(
# --> 104                     lambda f: pc.load(f, encoding=encoding, compat=False))
#     105             # compat pickle
#
# ~\Anaconda3\lib\site-packages\pandas\io\pickle.py in read_wrapper(func)
#      81                             compression=inferred_compression,
# ---> 82                             is_text=False)
#      83         try:
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     395             # Python 3 and binary mode
# --> 396             f = open(path_or_buf, mode)
#     397         handles.append(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'df_train.pickle'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\io\pickle.py in read_pickle(path, compression)
#     109     try:
# --> 110         return try_read(path)
#     111     except:
#
# ~\Anaconda3\lib\site-packages\pandas\io\pickle.py in try_read(path, encoding)
#     107                 return read_wrapper(
# --> 108                     lambda f: pc.load(f, encoding=encoding, compat=True))
#     109     try:
#
# ~\Anaconda3\lib\site-packages\pandas\io\pickle.py in read_wrapper(func)
#      81                             compression=inferred_compression,
# ---> 82                             is_text=False)
#      83         try:
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     395             # Python 3 and binary mode
# --> 396             f = open(path_or_buf, mode)
#     397         handles.append(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'df_train.pickle'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\io\pickle.py in try_read(path, encoding)
#      98         try:
# ---> 99             return read_wrapper(lambda f: pkl.load(f))
#     100         except Exception:
#
# ~\Anaconda3\lib\site-packages\pandas\io\pickle.py in read_wrapper(func)
#      81                             compression=inferred_compression,
# ---> 82                             is_text=False)
#      83         try:
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     395             # Python 3 and binary mode
# --> 396             f = open(path_or_buf, mode)
#     397         handles.append(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'df_train.pickle'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\io\pickle.py in try_read(path, encoding)
#     103                 return read_wrapper(
# --> 104                     lambda f: pc.load(f, encoding=encoding, compat=False))
#     105             # compat pickle
#
# ~\Anaconda3\lib\site-packages\pandas\io\pickle.py in read_wrapper(func)
#      81                             compression=inferred_compression,
# ---> 82                             is_text=False)
#      83         try:
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     395             # Python 3 and binary mode
# --> 396             f = open(path_or_buf, mode)
#     397         handles.append(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'df_train.pickle'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-ec2fa623dc38> in <module>()
# ----> 1 train = pd.read_pickle('df_train.pickle')
#       2 test = pd.read_pickle('df_test.pickle')
#       3
#       4 target = np.loadtxt('wang.target.txt')
#       5 outlier = np.zeros(len(target), dtype=np.int)
#
# ~\Anaconda3\lib\site-packages\pandas\io\pickle.py in read_pickle(path, compression)
#     111     except:
#     112         if PY3:
# --> 113             return try_read(path, encoding='latin1')
#     114         raise
#     115
#
# ~\Anaconda3\lib\site-packages\pandas\io\pickle.py in try_read(path, encoding)
#     106             except:
#     107                 return read_wrapper(
# --> 108                     lambda f: pc.load(f, encoding=encoding, compat=True))
#     109     try:
#     110         return try_read(path)
#
# ~\Anaconda3\lib\site-packages\pandas\io\pickle.py in read_wrapper(func)
#      80         f, fh = _get_handle(path, 'rb',
#      81                             compression=inferred_compression,
# ---> 82                             is_text=False)
#      83         try:
#      84             return func(f)
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     394         else:
#     395             # Python 3 and binary mode
# --> 396             f = open(path_or_buf, mode)
#     397         handles.append(f)
#     398
#
# FileNotFoundError: [Errno 2] No such file or directory: 'df_train.pickle'

# %% [markdown]
# #### outlier ratio

# %%
outlier.sum() / len(outlier)
# Out:
# 0.010930233709890698

# %%
feats = [c for c in train.columns if c not in ['card_id', 'first_active_month','target','outliers']]

# %%
target_with_outlier = pd.DataFrame({
    'target': target,
    'outlier': outlier
})

# %% [markdown]
# #### because test/(test+train) = 0.38, we use test_size=0.38

# %%
X_tr, X_va, y_tr, y_va = train_test_split(train[feats].values, target_with_outlier, test_size=0.38, random_state=12)

# %%
X_tr.shape, X_va.shape, y_tr.shape, y_va.shape
# Out:
# ((125188, 250), (76729, 250), (125188, 2), (76729, 2))

# %%
def get_lb(pred_target):
    return mean_squared_error(y_va.target, pred_target) ** 0.5

# %% [markdown]
# ### outlier detection

# %%
cl_param = {
         'num_leaves': 31,
         'min_data_in_leaf': 20, 
         'objective':'binary',
         'max_depth': -1,
         'learning_rate': 0.01,
         "boosting": "gbdt",
         "feature_fraction": 0.9, #
         "bagging_freq": 1,
         "bagging_fraction": 0.9, #
         "metric": 'auc',
         "lambda_l1": 0.1,
         "verbosity": -1,
         "nthread": 48,
         "scale_pos_weight": 15,
}

# %%
tr_data = lgb.Dataset(X_tr, label=y_tr.outlier)

# %%
cv_score = lgb.cv(cl_param, tr_data, 10000, early_stopping_rounds=600, verbose_eval=100)
# Out:
# [100]	cv_agg's auc: 0.902991 + 0.00631904
# [200]	cv_agg's auc: 0.904106 + 0.0061521
# [300]	cv_agg's auc: 0.903997 + 0.00618317
# [400]	cv_agg's auc: 0.903478 + 0.00630076
# [500]	cv_agg's auc: 0.902737 + 0.00635599
# [600]	cv_agg's auc: 0.901914 + 0.00631457
# [700]	cv_agg's auc: 0.901365 + 0.00640091
# [800]	cv_agg's auc: 0.900788 + 0.00680034

# %%
print('best num: ', len(cv_score['auc-mean']), '\nbest score:', cv_score['auc-mean'][-1])
# Out:
# best num:  234
# best score: 0.9043001536208134

# %%
clf = lgb.train(cl_param, tr_data, 400, valid_sets=(tr_data), verbose_eval=100)
# Out:
# [100]	training's auc: 0.966946
# [200]	training's auc: 0.974508
# [300]	training's auc: 0.980274
# [400]	training's auc: 0.984884

# %%
prob = clf.predict(X_va, num_iteration=clf.best_iteration)

# %%
roc_auc_score(y_va.outlier, prob)
# Out:
# 0.9021780628539581

# %%
fpr, tpr, thr = roc_curve(y_va.outlier, prob)

# %%
plt.plot(fpr, tpr)

# %%
print('outlier:', y_va.outlier.sum(), '\nnot outlier:', y_va.shape[0] - y_va.outlier.sum())
# Out:
# outlier: 869
# not outlier: 75860

# %%
for i in range(len(fpr)):
    real_outlier = int(tpr[i]*1351)
    not_outlier = int(fpr[i]*122272)
    total = real_outlier + not_outlier
    print(f'top {total}:  \toutlier {real_outlier} \t not outlier {not_outlier}')
# Out:
# top 0:  	outlier 0 	 not outlier 0
# top 1:  	outlier 1 	 not outlier 0
# top 7:  	outlier 1 	 not outlier 6
# top 9:  	outlier 3 	 not outlier 6
# top 15:  	outlier 3 	 not outlier 12
# top 16:  	outlier 4 	 not outlier 12
# top 20:  	outlier 4 	 not outlier 16
# top 23:  	outlier 7 	 not outlier 16
# top 24:  	outlier 7 	 not outlier 17
# top 29:  	outlier 12 	 not outlier 17
# top 36:  	outlier 12 	 not outlier 24
# top 39:  	outlier 15 	 not outlier 24
# top 40:  	outlier 15 	 not outlier 25
# top 42:  	outlier 17 	 not outlier 25
# top 44:  	outlier 17 	 not outlier 27
# top 45:  	outlier 18 	 not outlier 27
# top 47:  	outlier 18 	 not outlier 29
# top 49:  	outlier 20 	 not outlier 29
# top 57:  	outlier 20 	 not outlier 37
# top 60:  	outlier 23 	 not outlier 37
# top 63:  	outlier 23 	 not outlier 40
# top 64:  	outlier 24 	 not outlier 40
# top 69:  	outlier 24 	 not outlier 45
# top 71:  	outlier 26 	 not outlier 45
# top 74:  	outlier 26 	 not outlier 48
# top 75:  	outlier 27 	 not outlier 48
# top 86:  	outlier 27 	 not outlier 59
# top 88:  	outlier 29 	 not outlier 59
# top 101:  	outlier 29 	 not outlier 72
# top 106:  	outlier 34 	 not outlier 72
# top 109:  	outlier 34 	 not outlier 75
# top 110:  	outlier 35 	 not outlier 75
# top 123:  	outlier 35 	 not outlier 88
# top 125:  	outlier 37 	 not outlier 88
# top 127:  	outlier 37 	 not outlier 90
# top 128:  	outlier 38 	 not outlier 90
# top 129:  	outlier 38 	 not outlier 91
# top 131:  	outlier 40 	 not outlier 91
# top 143:  	outlier 40 	 not outlier 103
# top 149:  	outlier 46 	 not outlier 103
# top 155:  	outlier 46 	 not outlier 109
# top 157:  	outlier 48 	 not outlier 109
# top 162:  	outlier 48 	 not outlier 114
# top 163:  	outlier 49 	 not outlier 114
# top 166:  	outlier 49 	 not outlier 117
# top 169:  	outlier 52 	 not outlier 117
# top 171:  	outlier 52 	 not outlier 119
# top 173:  	outlier 54 	 not outlier 119
# top 174:  	outlier 54 	 not outlier 120
# top 175:  	outlier 55 	 not outlier 120
# top 177:  	outlier 55 	 not outlier 122
# top 181:  	outlier 59 	 not outlier 122
# top 186:  	outlier 59 	 not outlier 127
# top 187:  	outlier 60 	 not outlier 127
# top 190:  	outlier 60 	 not outlier 130
# top 192:  	outlier 62 	 not outlier 130
# top 199:  	outlier 62 	 not outlier 137
# top 200:  	outlier 63 	 not outlier 137
# top 203:  	outlier 63 	 not outlier 140
# top 205:  	outlier 65 	 not outlier 140
# top 206:  	outlier 65 	 not outlier 141
# top 207:  	outlier 66 	 not outlier 141
# top 209:  	outlier 66 	 not outlier 143
# top 214:  	outlier 71 	 not outlier 143
# top 217:  	outlier 71 	 not outlier 146
# top 220:  	outlier 74 	 not outlier 146
# top 225:  	outlier 74 	 not outlier 151
# top 227:  	outlier 76 	 not outlier 151
# top 233:  	outlier 76 	 not outlier 157
# top 234:  	outlier 77 	 not outlier 157
# top 236:  	outlier 77 	 not outlier 159
# top 238:  	outlier 79 	 not outlier 159
# top 240:  	outlier 79 	 not outlier 161
# top 243:  	outlier 82 	 not outlier 161
# top 252:  	outlier 82 	 not outlier 170
# top 253:  	outlier 83 	 not outlier 170
# top 255:  	outlier 83 	 not outlier 172
# top 257:  	outlier 85 	 not outlier 172
# top 265:  	outlier 85 	 not outlier 180
# top 270:  	outlier 90 	 not outlier 180
# top 275:  	outlier 90 	 not outlier 185
# top 276:  	outlier 91 	 not outlier 185
# top 277:  	outlier 91 	 not outlier 186
# top 279:  	outlier 93 	 not outlier 186
# top 281:  	outlier 93 	 not outlier 188
# top 282:  	outlier 94 	 not outlier 188
# top 284:  	outlier 94 	 not outlier 190
# top 286:  	outlier 96 	 not outlier 190
# top 287:  	outlier 96 	 not outlier 191
# top 288:  	outlier 97 	 not outlier 191
# top 296:  	outlier 97 	 not outlier 199
# top 298:  	outlier 99 	 not outlier 199
# top 313:  	outlier 99 	 not outlier 214
# top 315:  	outlier 101 	 not outlier 214
# top 316:  	outlier 101 	 not outlier 215
# top 317:  	outlier 102 	 not outlier 215
# top 322:  	outlier 102 	 not outlier 220
# top 324:  	outlier 104 	 not outlier 220
# top 339:  	outlier 104 	 not outlier 235
# top 340:  	outlier 105 	 not outlier 235
# top 345:  	outlier 105 	 not outlier 240
# top 347:  	outlier 107 	 not outlier 240
# top 348:  	outlier 107 	 not outlier 241
# top 349:  	outlier 108 	 not outlier 241
# top 352:  	outlier 108 	 not outlier 244
# top 354:  	outlier 110 	 not outlier 244
# top 369:  	outlier 110 	 not outlier 259
# top 374:  	outlier 115 	 not outlier 259
# top 384:  	outlier 115 	 not outlier 269
# top 388:  	outlier 119 	 not outlier 269
# top 412:  	outlier 119 	 not outlier 293
# top 415:  	outlier 122 	 not outlier 293
# top 418:  	outlier 122 	 not outlier 296
# top 420:  	outlier 124 	 not outlier 296
# top 427:  	outlier 124 	 not outlier 303
# top 432:  	outlier 129 	 not outlier 303
# top 436:  	outlier 129 	 not outlier 307
# top 437:  	outlier 130 	 not outlier 307
# top 442:  	outlier 130 	 not outlier 312
# top 444:  	outlier 132 	 not outlier 312
# top 446:  	outlier 132 	 not outlier 314
# top 449:  	outlier 135 	 not outlier 314
# top 450:  	outlier 135 	 not outlier 315
# top 451:  	outlier 136 	 not outlier 315
# top 455:  	outlier 136 	 not outlier 319
# top 458:  	outlier 139 	 not outlier 319
# top 461:  	outlier 139 	 not outlier 322
# top 463:  	outlier 141 	 not outlier 322
# top 474:  	outlier 141 	 not outlier 333
# top 476:  	outlier 143 	 not outlier 333
# top 487:  	outlier 143 	 not outlier 344
# top 488:  	outlier 144 	 not outlier 344
# top 490:  	outlier 144 	 not outlier 346
# top 492:  	outlier 146 	 not outlier 346
# top 500:  	outlier 146 	 not outlier 354
# top 501:  	outlier 147 	 not outlier 354
# top 508:  	outlier 147 	 not outlier 361
# top 510:  	outlier 149 	 not outlier 361
# top 524:  	outlier 149 	 not outlier 375
# top 525:  	outlier 150 	 not outlier 375
# top 533:  	outlier 150 	 not outlier 383
# top 535:  	outlier 152 	 not outlier 383
# top 538:  	outlier 152 	 not outlier 386
# top 539:  	outlier 153 	 not outlier 386
# top 543:  	outlier 153 	 not outlier 390
# top 545:  	outlier 155 	 not outlier 390
# top 557:  	outlier 155 	 not outlier 402
# top 559:  	outlier 157 	 not outlier 402
# top 566:  	outlier 157 	 not outlier 409
# top 567:  	outlier 158 	 not outlier 409
# top 572:  	outlier 158 	 not outlier 414
# top 574:  	outlier 160 	 not outlier 414
# top 582:  	outlier 160 	 not outlier 422
# top 583:  	outlier 161 	 not outlier 422
# top 589:  	outlier 161 	 not outlier 428
# top 591:  	outlier 163 	 not outlier 428
# top 593:  	outlier 163 	 not outlier 430
# top 594:  	outlier 164 	 not outlier 430
# top 595:  	outlier 164 	 not outlier 431
# top 598:  	outlier 167 	 not outlier 431
# top 600:  	outlier 167 	 not outlier 433
# top 604:  	outlier 171 	 not outlier 433
# top 614:  	outlier 171 	 not outlier 443
# top 617:  	outlier 174 	 not outlier 443
# top 639:  	outlier 174 	 not outlier 465
# top 642:  	outlier 177 	 not outlier 465
# top 647:  	outlier 177 	 not outlier 470
# top 648:  	outlier 178 	 not outlier 470
# top 658:  	outlier 178 	 not outlier 480
# top 661:  	outlier 181 	 not outlier 480
# top 666:  	outlier 181 	 not outlier 485
# top 668:  	outlier 183 	 not outlier 485
# top 669:  	outlier 183 	 not outlier 486
# top 671:  	outlier 185 	 not outlier 486
# top 679:  	outlier 185 	 not outlier 494
# top 680:  	outlier 186 	 not outlier 494
# top 682:  	outlier 186 	 not outlier 496
# top 684:  	outlier 188 	 not outlier 496
# top 692:  	outlier 188 	 not outlier 504
# top 693:  	outlier 189 	 not outlier 504
# top 699:  	outlier 189 	 not outlier 510
# top 702:  	outlier 192 	 not outlier 510
# top 706:  	outlier 192 	 not outlier 514
# top 711:  	outlier 197 	 not outlier 514
# top 712:  	outlier 197 	 not outlier 515
# top 713:  	outlier 198 	 not outlier 515
# top 720:  	outlier 198 	 not outlier 522
# top 722:  	outlier 200 	 not outlier 522
# top 749:  	outlier 200 	 not outlier 549
# top 751:  	outlier 202 	 not outlier 549
# top 753:  	outlier 202 	 not outlier 551
# top 757:  	outlier 206 	 not outlier 551
# top 762:  	outlier 206 	 not outlier 556
# top 765:  	outlier 209 	 not outlier 556
# top 771:  	outlier 209 	 not outlier 562
# top 773:  	outlier 211 	 not outlier 562
# top 779:  	outlier 211 	 not outlier 568
# top 780:  	outlier 212 	 not outlier 568
# top 809:  	outlier 212 	 not outlier 597
# top 811:  	outlier 214 	 not outlier 597
# top 826:  	outlier 214 	 not outlier 612
# top 828:  	outlier 216 	 not outlier 612
# top 831:  	outlier 216 	 not outlier 615
# top 832:  	outlier 217 	 not outlier 615
# top 835:  	outlier 217 	 not outlier 618
# top 837:  	outlier 219 	 not outlier 618
# top 842:  	outlier 219 	 not outlier 623
# top 843:  	outlier 220 	 not outlier 623
# top 848:  	outlier 220 	 not outlier 628
# top 850:  	outlier 222 	 not outlier 628
# top 869:  	outlier 222 	 not outlier 647
# top 870:  	outlier 223 	 not outlier 647
# top 877:  	outlier 223 	 not outlier 654
# top 879:  	outlier 225 	 not outlier 654
# top 881:  	outlier 225 	 not outlier 656
# top 884:  	outlier 228 	 not outlier 656
# top 896:  	outlier 228 	 not outlier 668
# top 899:  	outlier 231 	 not outlier 668
# top 920:  	outlier 231 	 not outlier 689
# top 922:  	outlier 233 	 not outlier 689
# top 927:  	outlier 233 	 not outlier 694
# top 930:  	outlier 236 	 not outlier 694
# top 943:  	outlier 236 	 not outlier 707
# top 944:  	outlier 237 	 not outlier 707
# top 947:  	outlier 237 	 not outlier 710
# top 949:  	outlier 239 	 not outlier 710
# top 951:  	outlier 239 	 not outlier 712
# top 954:  	outlier 242 	 not outlier 712
# top 975:  	outlier 242 	 not outlier 733
# top 977:  	outlier 244 	 not outlier 733
# top 998:  	outlier 244 	 not outlier 754
# top 999:  	outlier 245 	 not outlier 754
# top 1004:  	outlier 245 	 not outlier 759
# top 1006:  	outlier 247 	 not outlier 759
# top 1014:  	outlier 247 	 not outlier 767
# top 1015:  	outlier 248 	 not outlier 767
# top 1024:  	outlier 248 	 not outlier 776
# top 1026:  	outlier 250 	 not outlier 776
# top 1038:  	outlier 250 	 not outlier 788
# top 1039:  	outlier 251 	 not outlier 788
# top 1056:  	outlier 251 	 not outlier 805
# top 1058:  	outlier 253 	 not outlier 805
# top 1063:  	outlier 253 	 not outlier 810
# top 1064:  	outlier 254 	 not outlier 810
# top 1066:  	outlier 254 	 not outlier 812
# top 1068:  	outlier 256 	 not outlier 812
# top 1073:  	outlier 256 	 not outlier 817
# top 1075:  	outlier 258 	 not outlier 817
# top 1115:  	outlier 258 	 not outlier 857
# top 1116:  	outlier 259 	 not outlier 857
# top 1126:  	outlier 259 	 not outlier 867
# top 1128:  	outlier 261 	 not outlier 867
# top 1132:  	outlier 261 	 not outlier 871
# top 1133:  	outlier 262 	 not outlier 871
# top 1142:  	outlier 262 	 not outlier 880
# top 1144:  	outlier 264 	 not outlier 880
# top 1152:  	outlier 264 	 not outlier 888
# top 1153:  	outlier 265 	 not outlier 888
# top 1156:  	outlier 265 	 not outlier 891
# top 1159:  	outlier 268 	 not outlier 891
# top 1160:  	outlier 268 	 not outlier 892
# top 1162:  	outlier 270 	 not outlier 892
# top 1177:  	outlier 270 	 not outlier 907
# top 1179:  	outlier 272 	 not outlier 907
# top 1184:  	outlier 272 	 not outlier 912
# top 1185:  	outlier 273 	 not outlier 912
# top 1225:  	outlier 273 	 not outlier 952
# top 1227:  	outlier 275 	 not outlier 952
# top 1238:  	outlier 275 	 not outlier 963
# top 1239:  	outlier 276 	 not outlier 963
# top 1254:  	outlier 276 	 not outlier 978
# top 1256:  	outlier 278 	 not outlier 978
# top 1262:  	outlier 278 	 not outlier 984
# top 1265:  	outlier 281 	 not outlier 984
# top 1269:  	outlier 281 	 not outlier 988
# top 1272:  	outlier 284 	 not outlier 988
# top 1280:  	outlier 284 	 not outlier 996
# top 1283:  	outlier 287 	 not outlier 996
# top 1286:  	outlier 287 	 not outlier 999
# top 1288:  	outlier 289 	 not outlier 999
# top 1289:  	outlier 289 	 not outlier 1000
# top 1290:  	outlier 290 	 not outlier 1000
# top 1313:  	outlier 290 	 not outlier 1023
# top 1315:  	outlier 292 	 not outlier 1023
# top 1317:  	outlier 292 	 not outlier 1025
# top 1318:  	outlier 293 	 not outlier 1025
# top 1332:  	outlier 293 	 not outlier 1039
# top 1334:  	outlier 295 	 not outlier 1039
# top 1339:  	outlier 295 	 not outlier 1044
# top 1340:  	outlier 296 	 not outlier 1044
# top 1345:  	outlier 296 	 not outlier 1049
# top 1347:  	outlier 298 	 not outlier 1049
# top 1360:  	outlier 298 	 not outlier 1062
# top 1362:  	outlier 300 	 not outlier 1062
# top 1363:  	outlier 300 	 not outlier 1063
# top 1364:  	outlier 301 	 not outlier 1063
# top 1384:  	outlier 301 	 not outlier 1083
# top 1386:  	outlier 303 	 not outlier 1083
# top 1397:  	outlier 303 	 not outlier 1094
# top 1401:  	outlier 307 	 not outlier 1094
# top 1411:  	outlier 307 	 not outlier 1104
# top 1413:  	outlier 309 	 not outlier 1104
# top 1417:  	outlier 309 	 not outlier 1108
# top 1418:  	outlier 310 	 not outlier 1108
# top 1423:  	outlier 310 	 not outlier 1113
# top 1427:  	outlier 314 	 not outlier 1113
# top 1435:  	outlier 314 	 not outlier 1121
# top 1438:  	outlier 317 	 not outlier 1121
# top 1442:  	outlier 317 	 not outlier 1125
# top 1443:  	outlier 318 	 not outlier 1125
# top 1451:  	outlier 318 	 not outlier 1133
# top 1453:  	outlier 320 	 not outlier 1133
# top 1456:  	outlier 320 	 not outlier 1136
# top 1457:  	outlier 321 	 not outlier 1136
# top 1473:  	outlier 321 	 not outlier 1152
# top 1475:  	outlier 323 	 not outlier 1152
# top 1477:  	outlier 323 	 not outlier 1154
# top 1478:  	outlier 324 	 not outlier 1154
# top 1484:  	outlier 324 	 not outlier 1160
# top 1486:  	outlier 326 	 not outlier 1160
# top 1492:  	outlier 326 	 not outlier 1166
# top 1494:  	outlier 328 	 not outlier 1166
# top 1504:  	outlier 328 	 not outlier 1176
# top 1507:  	outlier 331 	 not outlier 1176
# top 1522:  	outlier 331 	 not outlier 1191
# top 1523:  	outlier 332 	 not outlier 1191
# top 1527:  	outlier 332 	 not outlier 1195
# top 1530:  	outlier 335 	 not outlier 1195
# top 1534:  	outlier 335 	 not outlier 1199
# top 1536:  	outlier 337 	 not outlier 1199
# top 1550:  	outlier 337 	 not outlier 1213
# top 1551:  	outlier 338 	 not outlier 1213
# top 1553:  	outlier 338 	 not outlier 1215
# top 1555:  	outlier 340 	 not outlier 1215
# top 1585:  	outlier 340 	 not outlier 1245
# top 1587:  	outlier 342 	 not outlier 1245
# top 1602:  	outlier 342 	 not outlier 1260
# top 1603:  	outlier 343 	 not outlier 1260
# top 1606:  	outlier 343 	 not outlier 1263
# top 1608:  	outlier 345 	 not outlier 1263
# top 1619:  	outlier 345 	 not outlier 1274
# top 1620:  	outlier 346 	 not outlier 1274
# top 1629:  	outlier 346 	 not outlier 1283
# top 1631:  	outlier 348 	 not outlier 1283
# top 1640:  	outlier 348 	 not outlier 1292
# top 1641:  	outlier 349 	 not outlier 1292
# top 1643:  	outlier 349 	 not outlier 1294
# top 1645:  	outlier 351 	 not outlier 1294
# top 1646:  	outlier 351 	 not outlier 1295
# top 1649:  	outlier 354 	 not outlier 1295
# top 1674:  	outlier 354 	 not outlier 1320
# top 1679:  	outlier 359 	 not outlier 1320
# top 1682:  	outlier 359 	 not outlier 1323
# top 1683:  	outlier 360 	 not outlier 1323
# top 1691:  	outlier 360 	 not outlier 1331
# top 1693:  	outlier 362 	 not outlier 1331
# top 1698:  	outlier 362 	 not outlier 1336
# top 1702:  	outlier 366 	 not outlier 1336
# top 1703:  	outlier 366 	 not outlier 1337
# top 1705:  	outlier 368 	 not outlier 1337
# top 1709:  	outlier 368 	 not outlier 1341
# top 1712:  	outlier 371 	 not outlier 1341
# top 1718:  	outlier 371 	 not outlier 1347
# top 1720:  	outlier 373 	 not outlier 1347
# top 1731:  	outlier 373 	 not outlier 1358
# top 1732:  	outlier 374 	 not outlier 1358
# top 1747:  	outlier 374 	 not outlier 1373
# top 1750:  	outlier 377 	 not outlier 1373
# top 1764:  	outlier 377 	 not outlier 1387
# top 1766:  	outlier 379 	 not outlier 1387
# top 1768:  	outlier 379 	 not outlier 1389
# top 1769:  	outlier 380 	 not outlier 1389
# top 1801:  	outlier 380 	 not outlier 1421
# top 1803:  	outlier 382 	 not outlier 1421
# top 1813:  	outlier 382 	 not outlier 1431
# top 1815:  	outlier 384 	 not outlier 1431
# top 1821:  	outlier 384 	 not outlier 1437
# top 1822:  	outlier 385 	 not outlier 1437
# top 1825:  	outlier 385 	 not outlier 1440
# top 1827:  	outlier 387 	 not outlier 1440
# top 1856:  	outlier 387 	 not outlier 1469
# top 1857:  	outlier 388 	 not outlier 1469
# top 1859:  	outlier 388 	 not outlier 1471
# top 1862:  	outlier 391 	 not outlier 1471
# top 1889:  	outlier 391 	 not outlier 1498
# top 1894:  	outlier 396 	 not outlier 1498
# top 1901:  	outlier 396 	 not outlier 1505
# top 1902:  	outlier 397 	 not outlier 1505
# top 1907:  	outlier 397 	 not outlier 1510
# top 1909:  	outlier 399 	 not outlier 1510
# top 1931:  	outlier 399 	 not outlier 1532
# top 1933:  	outlier 401 	 not outlier 1532
# top 1935:  	outlier 401 	 not outlier 1534
# top 1936:  	outlier 402 	 not outlier 1534
# top 1938:  	outlier 402 	 not outlier 1536
# top 1940:  	outlier 404 	 not outlier 1536
# top 1959:  	outlier 404 	 not outlier 1555
# top 1960:  	outlier 405 	 not outlier 1555
# top 1966:  	outlier 405 	 not outlier 1561
# top 1968:  	outlier 407 	 not outlier 1561
# top 1986:  	outlier 407 	 not outlier 1579
# top 1987:  	outlier 408 	 not outlier 1579
# top 1990:  	outlier 408 	 not outlier 1582
# top 1993:  	outlier 411 	 not outlier 1582
# top 2000:  	outlier 411 	 not outlier 1589
# top 2002:  	outlier 413 	 not outlier 1589
# top 2003:  	outlier 413 	 not outlier 1590
# top 2005:  	outlier 415 	 not outlier 1590
# top 2007:  	outlier 415 	 not outlier 1592
# top 2008:  	outlier 416 	 not outlier 1592
# top 2022:  	outlier 416 	 not outlier 1606
# top 2025:  	outlier 419 	 not outlier 1606
# top 2027:  	outlier 419 	 not outlier 1608
# top 2029:  	outlier 421 	 not outlier 1608
# top 2036:  	outlier 421 	 not outlier 1615
# top 2037:  	outlier 422 	 not outlier 1615
# top 2056:  	outlier 422 	 not outlier 1634
# top 2058:  	outlier 424 	 not outlier 1634
# top 2064:  	outlier 424 	 not outlier 1640
# top 2065:  	outlier 425 	 not outlier 1640
# top 2070:  	outlier 425 	 not outlier 1645
# top 2072:  	outlier 427 	 not outlier 1645
# top 2101:  	outlier 427 	 not outlier 1674
# top 2103:  	outlier 429 	 not outlier 1674
# top 2148:  	outlier 429 	 not outlier 1719
# top 2149:  	outlier 430 	 not outlier 1719
# top 2154:  	outlier 430 	 not outlier 1724
# top 2157:  	outlier 433 	 not outlier 1724
# top 2160:  	outlier 433 	 not outlier 1727
# top 2162:  	outlier 435 	 not outlier 1727
# top 2167:  	outlier 435 	 not outlier 1732
# top 2168:  	outlier 436 	 not outlier 1732
# top 2173:  	outlier 436 	 not outlier 1737
# top 2175:  	outlier 438 	 not outlier 1737
# top 2181:  	outlier 438 	 not outlier 1743
# top 2182:  	outlier 439 	 not outlier 1743
# top 2192:  	outlier 439 	 not outlier 1753
# top 2194:  	outlier 441 	 not outlier 1753
# top 2228:  	outlier 441 	 not outlier 1787
# top 2230:  	outlier 443 	 not outlier 1787
# top 2282:  	outlier 443 	 not outlier 1839
# top 2283:  	outlier 444 	 not outlier 1839
# top 2320:  	outlier 444 	 not outlier 1876
# top 2322:  	outlier 446 	 not outlier 1876
# top 2326:  	outlier 446 	 not outlier 1880
# top 2327:  	outlier 447 	 not outlier 1880
# top 2390:  	outlier 447 	 not outlier 1943
# top 2392:  	outlier 449 	 not outlier 1943
# top 2417:  	outlier 449 	 not outlier 1968
# top 2418:  	outlier 450 	 not outlier 1968
# top 2422:  	outlier 450 	 not outlier 1972
# top 2424:  	outlier 452 	 not outlier 1972
# top 2426:  	outlier 452 	 not outlier 1974
# top 2427:  	outlier 453 	 not outlier 1974
# top 2440:  	outlier 453 	 not outlier 1987
# top 2442:  	outlier 455 	 not outlier 1987
# top 2447:  	outlier 455 	 not outlier 1992
# top 2449:  	outlier 457 	 not outlier 1992
# top 2466:  	outlier 457 	 not outlier 2009
# top 2467:  	outlier 458 	 not outlier 2009
# top 2479:  	outlier 458 	 not outlier 2021
# top 2481:  	outlier 460 	 not outlier 2021
# top 2492:  	outlier 460 	 not outlier 2032
# top 2493:  	outlier 461 	 not outlier 2032
# top 2516:  	outlier 461 	 not outlier 2055
# top 2518:  	outlier 463 	 not outlier 2055
# top 2527:  	outlier 463 	 not outlier 2064
# top 2528:  	outlier 464 	 not outlier 2064
# top 2531:  	outlier 464 	 not outlier 2067
# top 2533:  	outlier 466 	 not outlier 2067
# top 2543:  	outlier 466 	 not outlier 2077
# top 2544:  	outlier 467 	 not outlier 2077
# top 2557:  	outlier 467 	 not outlier 2090
# top 2559:  	outlier 469 	 not outlier 2090
# top 2574:  	outlier 469 	 not outlier 2105
# top 2576:  	outlier 471 	 not outlier 2105
# top 2579:  	outlier 471 	 not outlier 2108
# top 2580:  	outlier 472 	 not outlier 2108
# top 2614:  	outlier 472 	 not outlier 2142
# top 2616:  	outlier 474 	 not outlier 2142
# top 2632:  	outlier 474 	 not outlier 2158
# top 2635:  	outlier 477 	 not outlier 2158
# top 2636:  	outlier 477 	 not outlier 2159
# top 2637:  	outlier 478 	 not outlier 2159
# top 2647:  	outlier 478 	 not outlier 2169
# top 2650:  	outlier 481 	 not outlier 2169
# top 2656:  	outlier 481 	 not outlier 2175
# top 2658:  	outlier 483 	 not outlier 2175
# top 2689:  	outlier 483 	 not outlier 2206
# top 2691:  	outlier 485 	 not outlier 2206
# top 2696:  	outlier 485 	 not outlier 2211
# top 2697:  	outlier 486 	 not outlier 2211
# top 2703:  	outlier 486 	 not outlier 2217
# top 2705:  	outlier 488 	 not outlier 2217
# top 2725:  	outlier 488 	 not outlier 2237
# top 2726:  	outlier 489 	 not outlier 2237
# top 2742:  	outlier 489 	 not outlier 2253
# top 2744:  	outlier 491 	 not outlier 2253
# top 2750:  	outlier 491 	 not outlier 2259
# top 2751:  	outlier 492 	 not outlier 2259
# top 2759:  	outlier 492 	 not outlier 2267
# top 2761:  	outlier 494 	 not outlier 2267
# top 2776:  	outlier 494 	 not outlier 2282
# top 2777:  	outlier 495 	 not outlier 2282
# top 2780:  	outlier 495 	 not outlier 2285
# top 2782:  	outlier 497 	 not outlier 2285
# top 2784:  	outlier 497 	 not outlier 2287
# top 2786:  	outlier 499 	 not outlier 2287
# top 2800:  	outlier 499 	 not outlier 2301
# top 2801:  	outlier 500 	 not outlier 2301
# top 2804:  	outlier 500 	 not outlier 2304
# top 2806:  	outlier 502 	 not outlier 2304
# top 2810:  	outlier 502 	 not outlier 2308
# top 2811:  	outlier 503 	 not outlier 2308
# top 2817:  	outlier 503 	 not outlier 2314
# top 2819:  	outlier 505 	 not outlier 2314
# top 2840:  	outlier 505 	 not outlier 2335
# top 2841:  	outlier 506 	 not outlier 2335
# top 2844:  	outlier 506 	 not outlier 2338
# top 2846:  	outlier 508 	 not outlier 2338
# top 2853:  	outlier 508 	 not outlier 2345
# top 2858:  	outlier 513 	 not outlier 2345
# top 2861:  	outlier 513 	 not outlier 2348
# top 2862:  	outlier 514 	 not outlier 2348
# top 2905:  	outlier 514 	 not outlier 2391
# top 2907:  	outlier 516 	 not outlier 2391
# top 2944:  	outlier 516 	 not outlier 2428
# top 2945:  	outlier 517 	 not outlier 2428
# top 2947:  	outlier 517 	 not outlier 2430
# top 2949:  	outlier 519 	 not outlier 2430
# top 2970:  	outlier 519 	 not outlier 2451
# top 2971:  	outlier 520 	 not outlier 2451
# top 3011:  	outlier 520 	 not outlier 2491
# top 3013:  	outlier 522 	 not outlier 2491
# top 3058:  	outlier 522 	 not outlier 2536
# top 3059:  	outlier 523 	 not outlier 2536
# top 3066:  	outlier 523 	 not outlier 2543
# top 3068:  	outlier 525 	 not outlier 2543
# top 3071:  	outlier 525 	 not outlier 2546
# top 3073:  	outlier 527 	 not outlier 2546
# top 3075:  	outlier 527 	 not outlier 2548
# top 3076:  	outlier 528 	 not outlier 2548
# top 3079:  	outlier 528 	 not outlier 2551
# top 3081:  	outlier 530 	 not outlier 2551
# top 3084:  	outlier 530 	 not outlier 2554
# top 3085:  	outlier 531 	 not outlier 2554
# top 3132:  	outlier 531 	 not outlier 2601
# top 3134:  	outlier 533 	 not outlier 2601
# top 3186:  	outlier 533 	 not outlier 2653
# top 3187:  	outlier 534 	 not outlier 2653
# top 3269:  	outlier 534 	 not outlier 2735
# top 3271:  	outlier 536 	 not outlier 2735
# top 3308:  	outlier 536 	 not outlier 2772
# top 3309:  	outlier 537 	 not outlier 2772
# top 3314:  	outlier 537 	 not outlier 2777
# top 3316:  	outlier 539 	 not outlier 2777
# top 3335:  	outlier 539 	 not outlier 2796
# top 3337:  	outlier 541 	 not outlier 2796
# top 3342:  	outlier 541 	 not outlier 2801
# top 3343:  	outlier 542 	 not outlier 2801
# top 3349:  	outlier 542 	 not outlier 2807
# top 3351:  	outlier 544 	 not outlier 2807
# top 3358:  	outlier 544 	 not outlier 2814
# top 3359:  	outlier 545 	 not outlier 2814
# top 3385:  	outlier 545 	 not outlier 2840
# top 3387:  	outlier 547 	 not outlier 2840
# top 3407:  	outlier 547 	 not outlier 2860
# top 3408:  	outlier 548 	 not outlier 2860
# top 3426:  	outlier 548 	 not outlier 2878
# top 3428:  	outlier 550 	 not outlier 2878
# top 3430:  	outlier 550 	 not outlier 2880
# top 3431:  	outlier 551 	 not outlier 2880
# top 3484:  	outlier 551 	 not outlier 2933
# top 3486:  	outlier 553 	 not outlier 2933
# top 3588:  	outlier 553 	 not outlier 3035
# top 3590:  	outlier 555 	 not outlier 3035
# top 3596:  	outlier 555 	 not outlier 3041
# top 3597:  	outlier 556 	 not outlier 3041
# top 3618:  	outlier 556 	 not outlier 3062
# top 3620:  	outlier 558 	 not outlier 3062
# top 3638:  	outlier 558 	 not outlier 3080
# top 3639:  	outlier 559 	 not outlier 3080
# top 3674:  	outlier 559 	 not outlier 3115
# top 3676:  	outlier 561 	 not outlier 3115
# top 3760:  	outlier 561 	 not outlier 3199
# top 3761:  	outlier 562 	 not outlier 3199
# top 3772:  	outlier 562 	 not outlier 3210
# top 3774:  	outlier 564 	 not outlier 3210
# top 3826:  	outlier 564 	 not outlier 3262
# top 3827:  	outlier 565 	 not outlier 3262
# top 3849:  	outlier 565 	 not outlier 3284
# top 3851:  	outlier 567 	 not outlier 3284
# top 3876:  	outlier 567 	 not outlier 3309
# top 3878:  	outlier 569 	 not outlier 3309
# top 3881:  	outlier 569 	 not outlier 3312
# top 3882:  	outlier 570 	 not outlier 3312
# top 3890:  	outlier 570 	 not outlier 3320
# top 3892:  	outlier 572 	 not outlier 3320
# top 3905:  	outlier 572 	 not outlier 3333
# top 3906:  	outlier 573 	 not outlier 3333
# top 3911:  	outlier 573 	 not outlier 3338
# top 3913:  	outlier 575 	 not outlier 3338
# top 3934:  	outlier 575 	 not outlier 3359
# top 3935:  	outlier 576 	 not outlier 3359
# top 3939:  	outlier 576 	 not outlier 3363
# top 3941:  	outlier 578 	 not outlier 3363
# top 3964:  	outlier 578 	 not outlier 3386
# top 3965:  	outlier 579 	 not outlier 3386
# top 3967:  	outlier 579 	 not outlier 3388
# top 3969:  	outlier 581 	 not outlier 3388
# top 3972:  	outlier 581 	 not outlier 3391
# top 3975:  	outlier 584 	 not outlier 3391
# top 4004:  	outlier 584 	 not outlier 3420
# top 4006:  	outlier 586 	 not outlier 3420
# top 4017:  	outlier 586 	 not outlier 3431
# top 4018:  	outlier 587 	 not outlier 3431
# top 4074:  	outlier 587 	 not outlier 3487
# top 4076:  	outlier 589 	 not outlier 3487
# top 4093:  	outlier 589 	 not outlier 3504
# top 4094:  	outlier 590 	 not outlier 3504
# top 4115:  	outlier 590 	 not outlier 3525
# top 4117:  	outlier 592 	 not outlier 3525
# top 4118:  	outlier 592 	 not outlier 3526
# top 4121:  	outlier 595 	 not outlier 3526
# top 4128:  	outlier 595 	 not outlier 3533
# top 4129:  	outlier 596 	 not outlier 3533
# top 4132:  	outlier 596 	 not outlier 3536
# top 4134:  	outlier 598 	 not outlier 3536
# top 4147:  	outlier 598 	 not outlier 3549
# top 4149:  	outlier 600 	 not outlier 3549
# top 4213:  	outlier 600 	 not outlier 3613
# top 4214:  	outlier 601 	 not outlier 3613
# top 4225:  	outlier 601 	 not outlier 3624
# top 4227:  	outlier 603 	 not outlier 3624
# top 4256:  	outlier 603 	 not outlier 3653
# top 4257:  	outlier 604 	 not outlier 3653
# top 4278:  	outlier 604 	 not outlier 3674
# top 4280:  	outlier 606 	 not outlier 3674
# top 4288:  	outlier 606 	 not outlier 3682
# top 4289:  	outlier 607 	 not outlier 3682
# top 4306:  	outlier 607 	 not outlier 3699
# top 4308:  	outlier 609 	 not outlier 3699
# top 4317:  	outlier 609 	 not outlier 3708
# top 4318:  	outlier 610 	 not outlier 3708
# top 4336:  	outlier 610 	 not outlier 3726
# top 4338:  	outlier 612 	 not outlier 3726
# top 4349:  	outlier 612 	 not outlier 3737
# top 4351:  	outlier 614 	 not outlier 3737
# top 4369:  	outlier 614 	 not outlier 3755
# top 4370:  	outlier 615 	 not outlier 3755
# top 4376:  	outlier 615 	 not outlier 3761
# top 4378:  	outlier 617 	 not outlier 3761
# top 4382:  	outlier 617 	 not outlier 3765
# top 4383:  	outlier 618 	 not outlier 3765
# top 4399:  	outlier 618 	 not outlier 3781
# top 4401:  	outlier 620 	 not outlier 3781
# top 4402:  	outlier 620 	 not outlier 3782
# top 4405:  	outlier 623 	 not outlier 3782
# top 4430:  	outlier 623 	 not outlier 3807
# top 4431:  	outlier 624 	 not outlier 3807
# top 4448:  	outlier 624 	 not outlier 3824
# top 4450:  	outlier 626 	 not outlier 3824
# top 4463:  	outlier 626 	 not outlier 3837
# top 4465:  	outlier 628 	 not outlier 3837
# top 4467:  	outlier 628 	 not outlier 3839
# top 4468:  	outlier 629 	 not outlier 3839
# top 4478:  	outlier 629 	 not outlier 3849
# top 4480:  	outlier 631 	 not outlier 3849
# top 4573:  	outlier 631 	 not outlier 3942
# top 4574:  	outlier 632 	 not outlier 3942
# top 4576:  	outlier 632 	 not outlier 3944
# top 4578:  	outlier 634 	 not outlier 3944
# top 4582:  	outlier 634 	 not outlier 3948
# top 4583:  	outlier 635 	 not outlier 3948
# top 4651:  	outlier 635 	 not outlier 4016
# top 4653:  	outlier 637 	 not outlier 4016
# top 4690:  	outlier 637 	 not outlier 4053
# top 4691:  	outlier 638 	 not outlier 4053
# top 4722:  	outlier 638 	 not outlier 4084
# top 4724:  	outlier 640 	 not outlier 4084
# top 4725:  	outlier 640 	 not outlier 4085
# top 4727:  	outlier 642 	 not outlier 4085
# top 4752:  	outlier 642 	 not outlier 4110
# top 4753:  	outlier 643 	 not outlier 4110
# top 4785:  	outlier 643 	 not outlier 4142
# top 4787:  	outlier 645 	 not outlier 4142
# top 4811:  	outlier 645 	 not outlier 4166
# top 4812:  	outlier 646 	 not outlier 4166
# top 4815:  	outlier 646 	 not outlier 4169
# top 4817:  	outlier 648 	 not outlier 4169
# top 4819:  	outlier 648 	 not outlier 4171
# top 4820:  	outlier 649 	 not outlier 4171
# top 4847:  	outlier 649 	 not outlier 4198
# top 4849:  	outlier 651 	 not outlier 4198
# top 4852:  	outlier 651 	 not outlier 4201
# top 4853:  	outlier 652 	 not outlier 4201
# top 4865:  	outlier 652 	 not outlier 4213
# top 4867:  	outlier 654 	 not outlier 4213
# top 4938:  	outlier 654 	 not outlier 4284
# top 4940:  	outlier 656 	 not outlier 4284
# top 4953:  	outlier 656 	 not outlier 4297
# top 4954:  	outlier 657 	 not outlier 4297
# top 4989:  	outlier 657 	 not outlier 4332
# top 4991:  	outlier 659 	 not outlier 4332
# top 5025:  	outlier 659 	 not outlier 4366
# top 5026:  	outlier 660 	 not outlier 4366
# top 5031:  	outlier 660 	 not outlier 4371
# top 5033:  	outlier 662 	 not outlier 4371
# top 5054:  	outlier 662 	 not outlier 4392
# top 5055:  	outlier 663 	 not outlier 4392
# top 5089:  	outlier 663 	 not outlier 4426
# top 5091:  	outlier 665 	 not outlier 4426
# top 5140:  	outlier 665 	 not outlier 4475
# top 5141:  	outlier 666 	 not outlier 4475
# top 5161:  	outlier 666 	 not outlier 4495
# top 5163:  	outlier 668 	 not outlier 4495
# top 5164:  	outlier 668 	 not outlier 4496
# top 5166:  	outlier 670 	 not outlier 4496
# top 5191:  	outlier 670 	 not outlier 4521
# top 5192:  	outlier 671 	 not outlier 4521
# top 5201:  	outlier 671 	 not outlier 4530
# top 5203:  	outlier 673 	 not outlier 4530
# top 5271:  	outlier 673 	 not outlier 4598
# top 5272:  	outlier 674 	 not outlier 4598
# top 5295:  	outlier 674 	 not outlier 4621
# top 5298:  	outlier 677 	 not outlier 4621
# top 5309:  	outlier 677 	 not outlier 4632
# top 5311:  	outlier 679 	 not outlier 4632
# top 5343:  	outlier 679 	 not outlier 4664
# top 5344:  	outlier 680 	 not outlier 4664
# top 5349:  	outlier 680 	 not outlier 4669
# top 5351:  	outlier 682 	 not outlier 4669
# top 5373:  	outlier 682 	 not outlier 4691
# top 5375:  	outlier 684 	 not outlier 4691
# top 5424:  	outlier 684 	 not outlier 4740
# top 5425:  	outlier 685 	 not outlier 4740
# top 5444:  	outlier 685 	 not outlier 4759
# top 5446:  	outlier 687 	 not outlier 4759
# top 5449:  	outlier 687 	 not outlier 4762
# top 5450:  	outlier 688 	 not outlier 4762
# top 5458:  	outlier 688 	 not outlier 4770
# top 5460:  	outlier 690 	 not outlier 4770
# top 5464:  	outlier 690 	 not outlier 4774
# top 5465:  	outlier 691 	 not outlier 4774
# top 5503:  	outlier 691 	 not outlier 4812
# top 5505:  	outlier 693 	 not outlier 4812
# top 5542:  	outlier 693 	 not outlier 4849
# top 5543:  	outlier 694 	 not outlier 4849
# top 5547:  	outlier 694 	 not outlier 4853
# top 5549:  	outlier 696 	 not outlier 4853
# top 5557:  	outlier 696 	 not outlier 4861
# top 5559:  	outlier 698 	 not outlier 4861
# top 5675:  	outlier 698 	 not outlier 4977
# top 5676:  	outlier 699 	 not outlier 4977
# top 5710:  	outlier 699 	 not outlier 5011
# top 5712:  	outlier 701 	 not outlier 5011
# top 5733:  	outlier 701 	 not outlier 5032
# top 5734:  	outlier 702 	 not outlier 5032
# top 5750:  	outlier 702 	 not outlier 5048
# top 5752:  	outlier 704 	 not outlier 5048
# top 5789:  	outlier 704 	 not outlier 5085
# top 5790:  	outlier 705 	 not outlier 5085
# top 5807:  	outlier 705 	 not outlier 5102
# top 5809:  	outlier 707 	 not outlier 5102
# top 5835:  	outlier 707 	 not outlier 5128
# top 5836:  	outlier 708 	 not outlier 5128
# top 5841:  	outlier 708 	 not outlier 5133
# top 5843:  	outlier 710 	 not outlier 5133
# top 5850:  	outlier 710 	 not outlier 5140
# top 5852:  	outlier 712 	 not outlier 5140
# top 5926:  	outlier 712 	 not outlier 5214
# top 5927:  	outlier 713 	 not outlier 5214
# top 5938:  	outlier 713 	 not outlier 5225
# top 5940:  	outlier 715 	 not outlier 5225
# top 5998:  	outlier 715 	 not outlier 5283
# top 5999:  	outlier 716 	 not outlier 5283
# top 6014:  	outlier 716 	 not outlier 5298
# top 6016:  	outlier 718 	 not outlier 5298
# top 6048:  	outlier 718 	 not outlier 5330
# top 6049:  	outlier 719 	 not outlier 5330
# top 6073:  	outlier 719 	 not outlier 5354
# top 6075:  	outlier 721 	 not outlier 5354
# top 6081:  	outlier 721 	 not outlier 5360
# top 6082:  	outlier 722 	 not outlier 5360
# top 6150:  	outlier 722 	 not outlier 5428
# top 6152:  	outlier 724 	 not outlier 5428
# top 6163:  	outlier 724 	 not outlier 5439
# top 6165:  	outlier 726 	 not outlier 5439
# top 6169:  	outlier 726 	 not outlier 5443
# top 6170:  	outlier 727 	 not outlier 5443
# top 6171:  	outlier 727 	 not outlier 5444
# top 6173:  	outlier 729 	 not outlier 5444
# top 6178:  	outlier 729 	 not outlier 5449
# top 6179:  	outlier 730 	 not outlier 5449
# top 6282:  	outlier 730 	 not outlier 5552
# top 6284:  	outlier 732 	 not outlier 5552
# top 6297:  	outlier 732 	 not outlier 5565
# top 6298:  	outlier 733 	 not outlier 5565
# top 6308:  	outlier 733 	 not outlier 5575
# top 6310:  	outlier 735 	 not outlier 5575
# top 6318:  	outlier 735 	 not outlier 5583
# top 6319:  	outlier 736 	 not outlier 5583
# top 6324:  	outlier 736 	 not outlier 5588
# top 6326:  	outlier 738 	 not outlier 5588
# top 6342:  	outlier 738 	 not outlier 5604
# top 6344:  	outlier 740 	 not outlier 5604
# top 6345:  	outlier 740 	 not outlier 5605
# top 6346:  	outlier 741 	 not outlier 5605
# top 6387:  	outlier 741 	 not outlier 5646
# top 6389:  	outlier 743 	 not outlier 5646
# top 6443:  	outlier 743 	 not outlier 5700
# top 6444:  	outlier 744 	 not outlier 5700
# top 6449:  	outlier 744 	 not outlier 5705
# top 6451:  	outlier 746 	 not outlier 5705
# top 6535:  	outlier 746 	 not outlier 5789
# top 6536:  	outlier 747 	 not outlier 5789
# top 6555:  	outlier 747 	 not outlier 5808
# top 6558:  	outlier 750 	 not outlier 5808
# top 6620:  	outlier 750 	 not outlier 5870
# top 6622:  	outlier 752 	 not outlier 5870
# top 6638:  	outlier 752 	 not outlier 5886
# top 6640:  	outlier 754 	 not outlier 5886
# top 6641:  	outlier 754 	 not outlier 5887
# top 6642:  	outlier 755 	 not outlier 5887
# top 6660:  	outlier 755 	 not outlier 5905
# top 6662:  	outlier 757 	 not outlier 5905
# top 6665:  	outlier 757 	 not outlier 5908
# top 6666:  	outlier 758 	 not outlier 5908
# top 6732:  	outlier 758 	 not outlier 5974
# top 6734:  	outlier 760 	 not outlier 5974
# top 6739:  	outlier 760 	 not outlier 5979
# top 6740:  	outlier 761 	 not outlier 5979
# top 6792:  	outlier 761 	 not outlier 6031
# top 6794:  	outlier 763 	 not outlier 6031
# top 6805:  	outlier 763 	 not outlier 6042
# top 6806:  	outlier 764 	 not outlier 6042
# top 6851:  	outlier 764 	 not outlier 6087
# top 6855:  	outlier 768 	 not outlier 6087
# top 6868:  	outlier 768 	 not outlier 6100
# top 6869:  	outlier 769 	 not outlier 6100
# top 6976:  	outlier 769 	 not outlier 6207
# top 6978:  	outlier 771 	 not outlier 6207
# top 7097:  	outlier 771 	 not outlier 6326
# top 7098:  	outlier 772 	 not outlier 6326
# top 7169:  	outlier 772 	 not outlier 6397
# top 7172:  	outlier 775 	 not outlier 6397
# top 7198:  	outlier 775 	 not outlier 6423
# top 7200:  	outlier 777 	 not outlier 6423
# top 7214:  	outlier 777 	 not outlier 6437
# top 7215:  	outlier 778 	 not outlier 6437
# top 7305:  	outlier 778 	 not outlier 6527
# top 7307:  	outlier 780 	 not outlier 6527
# top 7352:  	outlier 780 	 not outlier 6572
# top 7353:  	outlier 781 	 not outlier 6572
# top 7397:  	outlier 781 	 not outlier 6616
# top 7399:  	outlier 783 	 not outlier 6616
# top 7518:  	outlier 783 	 not outlier 6735
# top 7520:  	outlier 785 	 not outlier 6735
# top 7544:  	outlier 785 	 not outlier 6759
# top 7545:  	outlier 786 	 not outlier 6759
# top 7639:  	outlier 786 	 not outlier 6853
# top 7641:  	outlier 788 	 not outlier 6853
# top 7707:  	outlier 788 	 not outlier 6919
# top 7708:  	outlier 789 	 not outlier 6919
# top 7713:  	outlier 789 	 not outlier 6924
# top 7715:  	outlier 791 	 not outlier 6924
# top 7797:  	outlier 791 	 not outlier 7006
# top 7798:  	outlier 792 	 not outlier 7006
# top 7848:  	outlier 792 	 not outlier 7056
# top 7850:  	outlier 794 	 not outlier 7056
# top 7852:  	outlier 794 	 not outlier 7058
# top 7853:  	outlier 795 	 not outlier 7058
# top 7907:  	outlier 795 	 not outlier 7112
# top 7909:  	outlier 797 	 not outlier 7112
# top 7951:  	outlier 797 	 not outlier 7154
# top 7953:  	outlier 799 	 not outlier 7154
# top 7960:  	outlier 799 	 not outlier 7161
# top 7961:  	outlier 800 	 not outlier 7161
# top 8009:  	outlier 800 	 not outlier 7209
# top 8011:  	outlier 802 	 not outlier 7209
# top 8109:  	outlier 802 	 not outlier 7307
# top 8110:  	outlier 803 	 not outlier 7307
# top 8115:  	outlier 803 	 not outlier 7312
# top 8117:  	outlier 805 	 not outlier 7312
# top 8124:  	outlier 805 	 not outlier 7319
# top 8125:  	outlier 806 	 not outlier 7319
# top 8147:  	outlier 806 	 not outlier 7341
# top 8149:  	outlier 808 	 not outlier 7341
# top 8214:  	outlier 808 	 not outlier 7406
# top 8215:  	outlier 809 	 not outlier 7406
# top 8361:  	outlier 809 	 not outlier 7552
# top 8363:  	outlier 811 	 not outlier 7552
# top 8365:  	outlier 811 	 not outlier 7554
# top 8367:  	outlier 813 	 not outlier 7554
# top 8396:  	outlier 813 	 not outlier 7583
# top 8397:  	outlier 814 	 not outlier 7583
# top 8399:  	outlier 814 	 not outlier 7585
# top 8401:  	outlier 816 	 not outlier 7585
# top 8446:  	outlier 816 	 not outlier 7630
# top 8447:  	outlier 817 	 not outlier 7630
# top 8519:  	outlier 817 	 not outlier 7702
# top 8521:  	outlier 819 	 not outlier 7702
# top 8542:  	outlier 819 	 not outlier 7723
# top 8543:  	outlier 820 	 not outlier 7723
# top 8545:  	outlier 820 	 not outlier 7725
# top 8548:  	outlier 823 	 not outlier 7725
# top 8643:  	outlier 823 	 not outlier 7820
# top 8645:  	outlier 825 	 not outlier 7820
# top 8698:  	outlier 825 	 not outlier 7873
# top 8700:  	outlier 827 	 not outlier 7873
# top 8716:  	outlier 827 	 not outlier 7889
# top 8717:  	outlier 828 	 not outlier 7889
# top 8721:  	outlier 828 	 not outlier 7893
# top 8724:  	outlier 831 	 not outlier 7893
# top 8761:  	outlier 831 	 not outlier 7930
# top 8763:  	outlier 833 	 not outlier 7930
# top 8776:  	outlier 833 	 not outlier 7943
# top 8777:  	outlier 834 	 not outlier 7943
# top 8785:  	outlier 834 	 not outlier 7951
# top 8787:  	outlier 836 	 not outlier 7951
# top 8830:  	outlier 836 	 not outlier 7994
# top 8831:  	outlier 837 	 not outlier 7994
# top 8855:  	outlier 837 	 not outlier 8018
# top 8857:  	outlier 839 	 not outlier 8018
# top 8914:  	outlier 839 	 not outlier 8075
# top 8916:  	outlier 841 	 not outlier 8075
# top 8958:  	outlier 841 	 not outlier 8117
# top 8959:  	outlier 842 	 not outlier 8117
# top 8992:  	outlier 842 	 not outlier 8150
# top 8994:  	outlier 844 	 not outlier 8150
# top 9011:  	outlier 844 	 not outlier 8167
# top 9012:  	outlier 845 	 not outlier 8167
# top 9033:  	outlier 845 	 not outlier 8188
# top 9035:  	outlier 847 	 not outlier 8188
# top 9136:  	outlier 847 	 not outlier 8289
# top 9137:  	outlier 848 	 not outlier 8289
# top 9147:  	outlier 848 	 not outlier 8299
# top 9149:  	outlier 850 	 not outlier 8299
# top 9160:  	outlier 850 	 not outlier 8310
# top 9161:  	outlier 851 	 not outlier 8310
# top 9163:  	outlier 851 	 not outlier 8312
# top 9165:  	outlier 853 	 not outlier 8312
# top 9226:  	outlier 853 	 not outlier 8373
# top 9228:  	outlier 855 	 not outlier 8373
# top 9452:  	outlier 855 	 not outlier 8597
# top 9453:  	outlier 856 	 not outlier 8597
# top 9456:  	outlier 856 	 not outlier 8600
# top 9458:  	outlier 858 	 not outlier 8600
# top 9479:  	outlier 858 	 not outlier 8621
# top 9480:  	outlier 859 	 not outlier 8621
# top 9509:  	outlier 859 	 not outlier 8650
# top 9512:  	outlier 862 	 not outlier 8650
# top 9585:  	outlier 862 	 not outlier 8723
# top 9587:  	outlier 864 	 not outlier 8723
# top 9624:  	outlier 864 	 not outlier 8760
# top 9625:  	outlier 865 	 not outlier 8760
# top 9720:  	outlier 865 	 not outlier 8855
# top 9722:  	outlier 867 	 not outlier 8855
# top 9746:  	outlier 867 	 not outlier 8879
# top 9748:  	outlier 869 	 not outlier 8879
# top 9780:  	outlier 869 	 not outlier 8911
# top 9781:  	outlier 870 	 not outlier 8911
# top 9812:  	outlier 870 	 not outlier 8942
# top 9814:  	outlier 872 	 not outlier 8942
# top 9848:  	outlier 872 	 not outlier 8976
# top 9849:  	outlier 873 	 not outlier 8976
# top 9984:  	outlier 873 	 not outlier 9111
# top 9986:  	outlier 875 	 not outlier 9111
# top 9999:  	outlier 875 	 not outlier 9124
# top 10000:  	outlier 876 	 not outlier 9124
# top 10014:  	outlier 876 	 not outlier 9138
# top 10016:  	outlier 878 	 not outlier 9138
# top 10023:  	outlier 878 	 not outlier 9145
# top 10024:  	outlier 879 	 not outlier 9145
# top 10087:  	outlier 879 	 not outlier 9208
# top 10089:  	outlier 881 	 not outlier 9208
# top 10115:  	outlier 881 	 not outlier 9234
# top 10117:  	outlier 883 	 not outlier 9234
# top 10295:  	outlier 883 	 not outlier 9412
# top 10296:  	outlier 884 	 not outlier 9412
# top 10384:  	outlier 884 	 not outlier 9500
# top 10386:  	outlier 886 	 not outlier 9500
# top 10476:  	outlier 886 	 not outlier 9590
# top 10477:  	outlier 887 	 not outlier 9590
# top 10503:  	outlier 887 	 not outlier 9616
# top 10505:  	outlier 889 	 not outlier 9616
# top 10521:  	outlier 889 	 not outlier 9632
# top 10522:  	outlier 890 	 not outlier 9632
# top 10583:  	outlier 890 	 not outlier 9693
# top 10585:  	outlier 892 	 not outlier 9693
# top 10614:  	outlier 892 	 not outlier 9722
# top 10615:  	outlier 893 	 not outlier 9722
# top 10654:  	outlier 893 	 not outlier 9761
# top 10656:  	outlier 895 	 not outlier 9761
# top 10659:  	outlier 895 	 not outlier 9764
# top 10661:  	outlier 897 	 not outlier 9764
# top 10664:  	outlier 897 	 not outlier 9767
# top 10665:  	outlier 898 	 not outlier 9767
# top 10676:  	outlier 898 	 not outlier 9778
# top 10678:  	outlier 900 	 not outlier 9778
# top 10744:  	outlier 900 	 not outlier 9844
# top 10745:  	outlier 901 	 not outlier 9844
# top 10747:  	outlier 901 	 not outlier 9846
# top 10749:  	outlier 903 	 not outlier 9846
# top 10752:  	outlier 903 	 not outlier 9849
# top 10753:  	outlier 904 	 not outlier 9849
# top 10757:  	outlier 904 	 not outlier 9853
# top 10759:  	outlier 906 	 not outlier 9853
# top 10783:  	outlier 906 	 not outlier 9877
# top 10784:  	outlier 907 	 not outlier 9877
# top 10809:  	outlier 907 	 not outlier 9902
# top 10811:  	outlier 909 	 not outlier 9902
# top 10818:  	outlier 909 	 not outlier 9909
# top 10820:  	outlier 911 	 not outlier 9909
# top 10921:  	outlier 911 	 not outlier 10010
# top 10924:  	outlier 914 	 not outlier 10010
# top 11000:  	outlier 914 	 not outlier 10086
# top 11001:  	outlier 915 	 not outlier 10086
# top 11009:  	outlier 915 	 not outlier 10094
# top 11011:  	outlier 917 	 not outlier 10094
# top 11063:  	outlier 917 	 not outlier 10146
# top 11064:  	outlier 918 	 not outlier 10146
# top 11072:  	outlier 918 	 not outlier 10154
# top 11074:  	outlier 920 	 not outlier 10154
# top 11098:  	outlier 920 	 not outlier 10178
# top 11099:  	outlier 921 	 not outlier 10178
# top 11152:  	outlier 921 	 not outlier 10231
# top 11154:  	outlier 923 	 not outlier 10231
# top 11206:  	outlier 923 	 not outlier 10283
# top 11208:  	outlier 925 	 not outlier 10283
# top 11317:  	outlier 925 	 not outlier 10392
# top 11318:  	outlier 926 	 not outlier 10392
# top 11488:  	outlier 926 	 not outlier 10562
# top 11490:  	outlier 928 	 not outlier 10562
# top 11694:  	outlier 928 	 not outlier 10766
# top 11695:  	outlier 929 	 not outlier 10766
# top 11710:  	outlier 929 	 not outlier 10781
# top 11712:  	outlier 931 	 not outlier 10781
# top 11826:  	outlier 931 	 not outlier 10895
# top 11827:  	outlier 932 	 not outlier 10895
# top 11850:  	outlier 932 	 not outlier 10918
# top 11852:  	outlier 934 	 not outlier 10918
# top 11857:  	outlier 934 	 not outlier 10923
# top 11858:  	outlier 935 	 not outlier 10923
# top 11969:  	outlier 935 	 not outlier 11034
# top 11971:  	outlier 937 	 not outlier 11034
# top 12122:  	outlier 937 	 not outlier 11185
# top 12125:  	outlier 940 	 not outlier 11185
# top 12142:  	outlier 940 	 not outlier 11202
# top 12144:  	outlier 942 	 not outlier 11202
# top 12211:  	outlier 942 	 not outlier 11269
# top 12212:  	outlier 943 	 not outlier 11269
# top 12386:  	outlier 943 	 not outlier 11443
# top 12388:  	outlier 945 	 not outlier 11443
# top 12504:  	outlier 945 	 not outlier 11559
# top 12505:  	outlier 946 	 not outlier 11559
# top 12552:  	outlier 946 	 not outlier 11606
# top 12554:  	outlier 948 	 not outlier 11606
# top 12556:  	outlier 948 	 not outlier 11608
# top 12557:  	outlier 949 	 not outlier 11608
# top 12592:  	outlier 949 	 not outlier 11643
# top 12594:  	outlier 951 	 not outlier 11643
# top 12636:  	outlier 951 	 not outlier 11685
# top 12638:  	outlier 953 	 not outlier 11685
# top 12857:  	outlier 953 	 not outlier 11904
# top 12860:  	outlier 956 	 not outlier 11904
# top 12881:  	outlier 956 	 not outlier 11925
# top 12882:  	outlier 957 	 not outlier 11925
# top 13048:  	outlier 957 	 not outlier 12091
# top 13050:  	outlier 959 	 not outlier 12091
# top 13324:  	outlier 959 	 not outlier 12365
# top 13325:  	outlier 960 	 not outlier 12365
# top 13348:  	outlier 960 	 not outlier 12388
# top 13350:  	outlier 962 	 not outlier 12388
# top 13609:  	outlier 962 	 not outlier 12647
# top 13610:  	outlier 963 	 not outlier 12647
# top 13704:  	outlier 963 	 not outlier 12741
# top 13706:  	outlier 965 	 not outlier 12741
# top 13746:  	outlier 965 	 not outlier 12781
# top 13747:  	outlier 966 	 not outlier 12781
# top 13807:  	outlier 966 	 not outlier 12841
# top 13809:  	outlier 968 	 not outlier 12841
# top 13830:  	outlier 968 	 not outlier 12862
# top 13832:  	outlier 970 	 not outlier 12862
# top 13869:  	outlier 970 	 not outlier 12899
# top 13870:  	outlier 971 	 not outlier 12899
# top 13970:  	outlier 971 	 not outlier 12999
# top 13972:  	outlier 973 	 not outlier 12999
# top 14036:  	outlier 973 	 not outlier 13063
# top 14037:  	outlier 974 	 not outlier 13063
# top 14055:  	outlier 974 	 not outlier 13081
# top 14057:  	outlier 976 	 not outlier 13081
# top 14092:  	outlier 976 	 not outlier 13116
# top 14093:  	outlier 977 	 not outlier 13116
# top 14122:  	outlier 977 	 not outlier 13145
# top 14124:  	outlier 979 	 not outlier 13145
# top 14207:  	outlier 979 	 not outlier 13228
# top 14208:  	outlier 980 	 not outlier 13228
# top 14316:  	outlier 980 	 not outlier 13336
# top 14318:  	outlier 982 	 not outlier 13336
# top 14356:  	outlier 982 	 not outlier 13374
# top 14358:  	outlier 984 	 not outlier 13374
# top 14374:  	outlier 984 	 not outlier 13390
# top 14375:  	outlier 985 	 not outlier 13390
# top 14380:  	outlier 985 	 not outlier 13395
# top 14382:  	outlier 987 	 not outlier 13395
# top 14767:  	outlier 987 	 not outlier 13780
# top 14768:  	outlier 988 	 not outlier 13780
# top 14844:  	outlier 988 	 not outlier 13856
# top 14846:  	outlier 990 	 not outlier 13856
# top 14887:  	outlier 990 	 not outlier 13897
# top 14888:  	outlier 991 	 not outlier 13897
# top 14899:  	outlier 991 	 not outlier 13908
# top 14901:  	outlier 993 	 not outlier 13908
# top 14972:  	outlier 993 	 not outlier 13979
# top 14973:  	outlier 994 	 not outlier 13979
# top 14978:  	outlier 994 	 not outlier 13984
# top 14980:  	outlier 996 	 not outlier 13984
# top 15018:  	outlier 996 	 not outlier 14022
# top 15020:  	outlier 998 	 not outlier 14022
# top 15046:  	outlier 998 	 not outlier 14048
# top 15047:  	outlier 999 	 not outlier 14048
# top 15074:  	outlier 999 	 not outlier 14075
# top 15076:  	outlier 1001 	 not outlier 14075
# top 15183:  	outlier 1001 	 not outlier 14182
# ...
# top 21772:  	outlier 1082 	 not outlier 20690
# top 21773:  	outlier 1083 	 not outlier 20690
# top 21907:  	outlier 1083 	 not outlier 20824
# top 21909:  	outlier 1085 	 not outlier 20824
# top 21961:  	outlier 1085 	 not outlier 20876
# top 21962:  	outlier 1086 	 not outlier 20876
# top 22008:  	outlier 1086 	 not outlier 20922
# top 22010:  	outlier 1088 	 not outlier 20922
# top 22151:  	outlier 1088 	 not outlier 21063
# top 22152:  	outlier 1089 	 not outlier 21063
# top 22185:  	outlier 1089 	 not outlier 21096
# top 22187:  	outlier 1091 	 not outlier 21096
# top 22202:  	outlier 1091 	 not outlier 21111
# top 22203:  	outlier 1092 	 not outlier 21111
# top 22290:  	outlier 1092 	 not outlier 21198
# top 22292:  	outlier 1094 	 not outlier 21198
# top 22324:  	outlier 1094 	 not outlier 21230
# top 22326:  	outlier 1096 	 not outlier 21230
# top 22346:  	outlier 1096 	 not outlier 21250
# top 22347:  	outlier 1097 	 not outlier 21250
# top 22363:  	outlier 1097 	 not outlier 21266
# top 22365:  	outlier 1099 	 not outlier 21266
# top 22515:  	outlier 1099 	 not outlier 21416
# top 22516:  	outlier 1100 	 not outlier 21416
# top 22728:  	outlier 1100 	 not outlier 21628
# top 22730:  	outlier 1102 	 not outlier 21628
# top 22774:  	outlier 1102 	 not outlier 21672
# top 22775:  	outlier 1103 	 not outlier 21672
# top 22843:  	outlier 1103 	 not outlier 21740
# top 22845:  	outlier 1105 	 not outlier 21740
# top 22849:  	outlier 1105 	 not outlier 21744
# top 22850:  	outlier 1106 	 not outlier 21744
# top 23286:  	outlier 1106 	 not outlier 22180
# top 23288:  	outlier 1108 	 not outlier 22180
# top 23476:  	outlier 1108 	 not outlier 22368
# top 23478:  	outlier 1110 	 not outlier 22368
# top 23502:  	outlier 1110 	 not outlier 22392
# top 23503:  	outlier 1111 	 not outlier 22392
# top 23552:  	outlier 1111 	 not outlier 22441
# top 23554:  	outlier 1113 	 not outlier 22441
# top 24095:  	outlier 1113 	 not outlier 22982
# top 24096:  	outlier 1114 	 not outlier 22982
# top 24264:  	outlier 1114 	 not outlier 23150
# top 24266:  	outlier 1116 	 not outlier 23150
# top 24506:  	outlier 1116 	 not outlier 23390
# top 24507:  	outlier 1117 	 not outlier 23390
# top 24586:  	outlier 1117 	 not outlier 23469
# top 24588:  	outlier 1119 	 not outlier 23469
# top 24891:  	outlier 1119 	 not outlier 23772
# top 24892:  	outlier 1120 	 not outlier 23772
# top 24963:  	outlier 1120 	 not outlier 23843
# top 24965:  	outlier 1122 	 not outlier 23843
# top 25020:  	outlier 1122 	 not outlier 23898
# top 25022:  	outlier 1124 	 not outlier 23898
# top 25204:  	outlier 1124 	 not outlier 24080
# top 25205:  	outlier 1125 	 not outlier 24080
# top 25700:  	outlier 1125 	 not outlier 24575
# top 25702:  	outlier 1127 	 not outlier 24575
# top 25757:  	outlier 1127 	 not outlier 24630
# top 25758:  	outlier 1128 	 not outlier 24630
# top 25809:  	outlier 1128 	 not outlier 24681
# top 25811:  	outlier 1130 	 not outlier 24681
# top 25872:  	outlier 1130 	 not outlier 24742
# top 25873:  	outlier 1131 	 not outlier 24742
# top 26002:  	outlier 1131 	 not outlier 24871
# top 26004:  	outlier 1133 	 not outlier 24871
# top 26143:  	outlier 1133 	 not outlier 25010
# top 26144:  	outlier 1134 	 not outlier 25010
# top 26283:  	outlier 1134 	 not outlier 25149
# top 26285:  	outlier 1136 	 not outlier 25149
# top 26341:  	outlier 1136 	 not outlier 25205
# top 26343:  	outlier 1138 	 not outlier 25205
# top 26603:  	outlier 1138 	 not outlier 25465
# top 26604:  	outlier 1139 	 not outlier 25465
# top 26645:  	outlier 1139 	 not outlier 25506
# top 26647:  	outlier 1141 	 not outlier 25506
# top 26784:  	outlier 1141 	 not outlier 25643
# top 26785:  	outlier 1142 	 not outlier 25643
# top 26955:  	outlier 1142 	 not outlier 25813
# top 26957:  	outlier 1144 	 not outlier 25813
# top 27323:  	outlier 1144 	 not outlier 26179
# top 27324:  	outlier 1145 	 not outlier 26179
# top 27954:  	outlier 1145 	 not outlier 26809
# top 27956:  	outlier 1147 	 not outlier 26809
# top 28051:  	outlier 1147 	 not outlier 26904
# top 28052:  	outlier 1148 	 not outlier 26904
# top 28307:  	outlier 1148 	 not outlier 27159
# top 28309:  	outlier 1150 	 not outlier 27159
# top 28350:  	outlier 1150 	 not outlier 27200
# top 28352:  	outlier 1152 	 not outlier 27200
# top 28443:  	outlier 1152 	 not outlier 27291
# top 28444:  	outlier 1153 	 not outlier 27291
# top 28619:  	outlier 1153 	 not outlier 27466
# top 28621:  	outlier 1155 	 not outlier 27466
# top 28650:  	outlier 1155 	 not outlier 27495
# top 28651:  	outlier 1156 	 not outlier 27495
# top 29565:  	outlier 1156 	 not outlier 28409
# top 29567:  	outlier 1158 	 not outlier 28409
# top 29572:  	outlier 1158 	 not outlier 28414
# top 29573:  	outlier 1159 	 not outlier 28414
# top 29647:  	outlier 1159 	 not outlier 28488
# top 29649:  	outlier 1161 	 not outlier 28488
# top 29762:  	outlier 1161 	 not outlier 28601
# top 29763:  	outlier 1162 	 not outlier 28601
# top 29863:  	outlier 1162 	 not outlier 28701
# top 29865:  	outlier 1164 	 not outlier 28701
# top 29899:  	outlier 1164 	 not outlier 28735
# top 29900:  	outlier 1165 	 not outlier 28735
# top 30193:  	outlier 1165 	 not outlier 29028
# top 30195:  	outlier 1167 	 not outlier 29028
# top 30274:  	outlier 1167 	 not outlier 29107
# top 30276:  	outlier 1169 	 not outlier 29107
# top 30895:  	outlier 1169 	 not outlier 29726
# top 30896:  	outlier 1170 	 not outlier 29726
# top 31296:  	outlier 1170 	 not outlier 30126
# top 31298:  	outlier 1172 	 not outlier 30126
# top 31591:  	outlier 1172 	 not outlier 30419
# top 31592:  	outlier 1173 	 not outlier 30419
# top 31608:  	outlier 1173 	 not outlier 30435
# top 31610:  	outlier 1175 	 not outlier 30435
# top 31768:  	outlier 1175 	 not outlier 30593
# top 31769:  	outlier 1176 	 not outlier 30593
# top 31774:  	outlier 1176 	 not outlier 30598
# top 31776:  	outlier 1178 	 not outlier 30598
# top 31894:  	outlier 1178 	 not outlier 30716
# top 31895:  	outlier 1179 	 not outlier 30716
# top 32277:  	outlier 1179 	 not outlier 31098
# top 32279:  	outlier 1181 	 not outlier 31098
# top 32358:  	outlier 1181 	 not outlier 31177
# top 32360:  	outlier 1183 	 not outlier 31177
# top 32653:  	outlier 1183 	 not outlier 31470
# top 32654:  	outlier 1184 	 not outlier 31470
# top 32788:  	outlier 1184 	 not outlier 31604
# top 32790:  	outlier 1186 	 not outlier 31604
# top 32845:  	outlier 1186 	 not outlier 31659
# top 32846:  	outlier 1187 	 not outlier 31659
# top 33039:  	outlier 1187 	 not outlier 31852
# top 33041:  	outlier 1189 	 not outlier 31852
# top 33607:  	outlier 1189 	 not outlier 32418
# top 33608:  	outlier 1190 	 not outlier 32418
# top 33661:  	outlier 1190 	 not outlier 32471
# top 33663:  	outlier 1192 	 not outlier 32471
# top 33690:  	outlier 1192 	 not outlier 32498
# top 33691:  	outlier 1193 	 not outlier 32498
# top 34003:  	outlier 1193 	 not outlier 32810
# top 34005:  	outlier 1195 	 not outlier 32810
# top 34079:  	outlier 1195 	 not outlier 32884
# top 34081:  	outlier 1197 	 not outlier 32884
# top 34401:  	outlier 1197 	 not outlier 33204
# top 34402:  	outlier 1198 	 not outlier 33204
# top 34428:  	outlier 1198 	 not outlier 33230
# top 34430:  	outlier 1200 	 not outlier 33230
# top 34485:  	outlier 1200 	 not outlier 33285
# top 34486:  	outlier 1201 	 not outlier 33285
# top 34650:  	outlier 1201 	 not outlier 33449
# top 34652:  	outlier 1203 	 not outlier 33449
# top 34807:  	outlier 1203 	 not outlier 33604
# top 34808:  	outlier 1204 	 not outlier 33604
# top 34827:  	outlier 1204 	 not outlier 33623
# top 34829:  	outlier 1206 	 not outlier 33623
# top 34842:  	outlier 1206 	 not outlier 33636
# top 34843:  	outlier 1207 	 not outlier 33636
# top 35193:  	outlier 1207 	 not outlier 33986
# top 35195:  	outlier 1209 	 not outlier 33986
# top 35242:  	outlier 1209 	 not outlier 34033
# top 35244:  	outlier 1211 	 not outlier 34033
# top 35455:  	outlier 1211 	 not outlier 34244
# top 35456:  	outlier 1212 	 not outlier 34244
# top 35522:  	outlier 1212 	 not outlier 34310
# top 35524:  	outlier 1214 	 not outlier 34310
# top 35972:  	outlier 1214 	 not outlier 34758
# top 35973:  	outlier 1215 	 not outlier 34758
# top 36175:  	outlier 1215 	 not outlier 34960
# top 36177:  	outlier 1217 	 not outlier 34960
# top 36225:  	outlier 1217 	 not outlier 35008
# top 36226:  	outlier 1218 	 not outlier 35008
# top 36405:  	outlier 1218 	 not outlier 35187
# top 36407:  	outlier 1220 	 not outlier 35187
# top 36762:  	outlier 1220 	 not outlier 35542
# top 36763:  	outlier 1221 	 not outlier 35542
# top 36958:  	outlier 1221 	 not outlier 35737
# top 36960:  	outlier 1223 	 not outlier 35737
# top 37340:  	outlier 1223 	 not outlier 36117
# top 37342:  	outlier 1225 	 not outlier 36117
# top 37394:  	outlier 1225 	 not outlier 36169
# top 37395:  	outlier 1226 	 not outlier 36169
# top 38075:  	outlier 1226 	 not outlier 36849
# top 38077:  	outlier 1228 	 not outlier 36849
# top 38359:  	outlier 1228 	 not outlier 37131
# top 38360:  	outlier 1229 	 not outlier 37131
# top 38408:  	outlier 1229 	 not outlier 37179
# top 38410:  	outlier 1231 	 not outlier 37179
# top 38882:  	outlier 1231 	 not outlier 37651
# top 38883:  	outlier 1232 	 not outlier 37651
# top 40390:  	outlier 1232 	 not outlier 39158
# top 40392:  	outlier 1234 	 not outlier 39158
# top 40923:  	outlier 1234 	 not outlier 39689
# top 40924:  	outlier 1235 	 not outlier 39689
# top 41008:  	outlier 1235 	 not outlier 39773
# top 41010:  	outlier 1237 	 not outlier 39773
# top 41279:  	outlier 1237 	 not outlier 40042
# top 41281:  	outlier 1239 	 not outlier 40042
# top 41648:  	outlier 1239 	 not outlier 40409
# top 41649:  	outlier 1240 	 not outlier 40409
# top 42283:  	outlier 1240 	 not outlier 41043
# top 42285:  	outlier 1242 	 not outlier 41043
# top 42310:  	outlier 1242 	 not outlier 41068
# top 42311:  	outlier 1243 	 not outlier 41068
# top 42527:  	outlier 1243 	 not outlier 41284
# top 42529:  	outlier 1245 	 not outlier 41284
# top 42671:  	outlier 1245 	 not outlier 41426
# top 42672:  	outlier 1246 	 not outlier 41426
# top 43051:  	outlier 1246 	 not outlier 41805
# top 43053:  	outlier 1248 	 not outlier 41805
# top 43280:  	outlier 1248 	 not outlier 42032
# top 43281:  	outlier 1249 	 not outlier 42032
# top 43470:  	outlier 1249 	 not outlier 42221
# top 43472:  	outlier 1251 	 not outlier 42221
# top 44054:  	outlier 1251 	 not outlier 42803
# top 44056:  	outlier 1253 	 not outlier 42803
# top 45286:  	outlier 1253 	 not outlier 44033
# top 45287:  	outlier 1254 	 not outlier 44033
# top 45346:  	outlier 1254 	 not outlier 44092
# top 45348:  	outlier 1256 	 not outlier 44092
# top 45933:  	outlier 1256 	 not outlier 44677
# top 45934:  	outlier 1257 	 not outlier 44677
# top 46224:  	outlier 1257 	 not outlier 44967
# top 46226:  	outlier 1259 	 not outlier 44967
# top 46346:  	outlier 1259 	 not outlier 45087
# top 46347:  	outlier 1260 	 not outlier 45087
# top 46916:  	outlier 1260 	 not outlier 45656
# top 46918:  	outlier 1262 	 not outlier 45656
# top 47174:  	outlier 1262 	 not outlier 45912
# top 47175:  	outlier 1263 	 not outlier 45912
# top 48437:  	outlier 1263 	 not outlier 47174
# top 48439:  	outlier 1265 	 not outlier 47174
# top 48515:  	outlier 1265 	 not outlier 47250
# top 48517:  	outlier 1267 	 not outlier 47250
# top 49136:  	outlier 1267 	 not outlier 47869
# top 49137:  	outlier 1268 	 not outlier 47869
# top 49472:  	outlier 1268 	 not outlier 48204
# top 49474:  	outlier 1270 	 not outlier 48204
# top 49808:  	outlier 1270 	 not outlier 48538
# top 49809:  	outlier 1271 	 not outlier 48538
# top 49880:  	outlier 1271 	 not outlier 48609
# top 49882:  	outlier 1273 	 not outlier 48609
# top 50199:  	outlier 1273 	 not outlier 48926
# top 50200:  	outlier 1274 	 not outlier 48926
# top 50235:  	outlier 1274 	 not outlier 48961
# top 50237:  	outlier 1276 	 not outlier 48961
# top 50587:  	outlier 1276 	 not outlier 49311
# top 50588:  	outlier 1277 	 not outlier 49311
# top 50875:  	outlier 1277 	 not outlier 49598
# top 50877:  	outlier 1279 	 not outlier 49598
# top 51183:  	outlier 1279 	 not outlier 49904
# top 51185:  	outlier 1281 	 not outlier 49904
# top 51667:  	outlier 1281 	 not outlier 50386
# top 51668:  	outlier 1282 	 not outlier 50386
# top 52381:  	outlier 1282 	 not outlier 51099
# top 52383:  	outlier 1284 	 not outlier 51099
# top 52828:  	outlier 1284 	 not outlier 51544
# top 52829:  	outlier 1285 	 not outlier 51544
# top 53248:  	outlier 1285 	 not outlier 51963
# top 53250:  	outlier 1287 	 not outlier 51963
# top 53664:  	outlier 1287 	 not outlier 52377
# top 53665:  	outlier 1288 	 not outlier 52377
# top 53942:  	outlier 1288 	 not outlier 52654
# top 53944:  	outlier 1290 	 not outlier 52654
# top 54748:  	outlier 1290 	 not outlier 53458
# top 54749:  	outlier 1291 	 not outlier 53458
# top 55072:  	outlier 1291 	 not outlier 53781
# top 55074:  	outlier 1293 	 not outlier 53781
# top 55582:  	outlier 1293 	 not outlier 54289
# top 55584:  	outlier 1295 	 not outlier 54289
# top 56767:  	outlier 1295 	 not outlier 55472
# top 56768:  	outlier 1296 	 not outlier 55472
# top 57428:  	outlier 1296 	 not outlier 56132
# top 57430:  	outlier 1298 	 not outlier 56132
# top 57551:  	outlier 1298 	 not outlier 56253
# top 57552:  	outlier 1299 	 not outlier 56253
# top 58266:  	outlier 1299 	 not outlier 56967
# top 58268:  	outlier 1301 	 not outlier 56967
# top 58584:  	outlier 1301 	 not outlier 57283
# top 58585:  	outlier 1302 	 not outlier 57283
# top 59581:  	outlier 1302 	 not outlier 58279
# top 59583:  	outlier 1304 	 not outlier 58279
# top 60323:  	outlier 1304 	 not outlier 59019
# top 60326:  	outlier 1307 	 not outlier 59019
# top 60734:  	outlier 1307 	 not outlier 59427
# top 60736:  	outlier 1309 	 not outlier 59427
# top 61250:  	outlier 1309 	 not outlier 59941
# top 61251:  	outlier 1310 	 not outlier 59941
# top 62433:  	outlier 1310 	 not outlier 61123
# top 62435:  	outlier 1312 	 not outlier 61123
# top 62754:  	outlier 1312 	 not outlier 61442
# top 62755:  	outlier 1313 	 not outlier 61442
# top 64041:  	outlier 1313 	 not outlier 62728
# top 64043:  	outlier 1315 	 not outlier 62728
# top 64593:  	outlier 1315 	 not outlier 63278
# top 64594:  	outlier 1316 	 not outlier 63278
# top 64955:  	outlier 1316 	 not outlier 63639
# top 64957:  	outlier 1318 	 not outlier 63639
# top 65074:  	outlier 1318 	 not outlier 63756
# top 65075:  	outlier 1319 	 not outlier 63756
# top 65158:  	outlier 1319 	 not outlier 63839
# top 65160:  	outlier 1321 	 not outlier 63839
# top 65179:  	outlier 1321 	 not outlier 63858
# top 65181:  	outlier 1323 	 not outlier 63858
# top 65289:  	outlier 1323 	 not outlier 63966
# top 65290:  	outlier 1324 	 not outlier 63966
# top 66520:  	outlier 1324 	 not outlier 65196
# top 66522:  	outlier 1326 	 not outlier 65196
# top 66815:  	outlier 1326 	 not outlier 65489
# top 66816:  	outlier 1327 	 not outlier 65489
# top 68346:  	outlier 1327 	 not outlier 67019
# top 68348:  	outlier 1329 	 not outlier 67019
# top 69113:  	outlier 1329 	 not outlier 67784
# top 69114:  	outlier 1330 	 not outlier 67784
# top 71090:  	outlier 1330 	 not outlier 69760
# top 71092:  	outlier 1332 	 not outlier 69760
# top 71096:  	outlier 1332 	 not outlier 69764
# top 71097:  	outlier 1333 	 not outlier 69764
# top 72605:  	outlier 1333 	 not outlier 71272
# top 72607:  	outlier 1335 	 not outlier 71272
# top 74335:  	outlier 1335 	 not outlier 73000
# top 74337:  	outlier 1337 	 not outlier 73000
# top 74445:  	outlier 1337 	 not outlier 73108
# top 74446:  	outlier 1338 	 not outlier 73108
# top 76906:  	outlier 1338 	 not outlier 75568
# top 76908:  	outlier 1340 	 not outlier 75568
# top 79274:  	outlier 1340 	 not outlier 77934
# top 79275:  	outlier 1341 	 not outlier 77934
# top 85145:  	outlier 1341 	 not outlier 83804
# top 85147:  	outlier 1343 	 not outlier 83804
# top 89148:  	outlier 1343 	 not outlier 87805
# top 89149:  	outlier 1344 	 not outlier 87805
# top 90309:  	outlier 1344 	 not outlier 88965
# top 90311:  	outlier 1346 	 not outlier 88965
# top 92161:  	outlier 1346 	 not outlier 90815
# top 92162:  	outlier 1347 	 not outlier 90815
# top 97122:  	outlier 1347 	 not outlier 95775
# top 97124:  	outlier 1349 	 not outlier 95775
# top 99806:  	outlier 1349 	 not outlier 98457
# top 99808:  	outlier 1351 	 not outlier 98457
# top 115771:  	outlier 1351 	 not outlier 114420
# top 115775:  	outlier 1351 	 not outlier 114424
# top 123623:  	outlier 1351 	 not outlier 122272

# %%
y_va_sort = y_va.copy()
y_va_sort['pred_prob'] = prob
y_va_sort = y_va_sort.sort_values('pred_prob', ascending=False)

# %%
y_va_sort.head()
# Out:
#           target  outlier  pred_prob
# 25347 -33.219281        1   0.861653
# 92357  -0.428425        0   0.837727
# 82035  -0.043868        0   0.837408
# 94554  -1.425834        0   0.834460
# 56803   2.033892        0   0.833689

# %%
y_va_sort.pred_prob.mean()
# Out:
# 0.06609684166346655

# %%
outlier.mean()
# Out:
# 0.010930233709890698

# %%
plt.plot(y_va_sort.pred_prob.values)

# %% [markdown]
# ### regression

# %%
rg_param = {
         'num_leaves': 31,
         'min_data_in_leaf': 20,
         'objective':'regression',
         'max_depth': -1,
         'learning_rate': 0.01,
         "boosting": "gbdt",
         "feature_fraction": 0.9,
         "bagging_freq": 1,
         "bagging_fraction": 0.9,
         "metric": 'rmse',
         "lambda_l1": 0.1,
         "verbosity": -1,
         "nthread": 48,
}

# %%
tr_data = lgb.Dataset(X_tr, label=y_tr.target)

# %%
cv_score = lgb.cv(rg_param, tr_data, 10000, early_stopping_rounds=600, verbose_eval=200, stratified=False)
# Out:
# [200]	cv_agg's rmse: 3.65388 + 0.120636
# [400]	cv_agg's rmse: 3.63575 + 0.11837
# [600]	cv_agg's rmse: 3.62999 + 0.117534
# [800]	cv_agg's rmse: 3.6281 + 0.117618
# [1000]	cv_agg's rmse: 3.62793 + 0.117438
# [1200]	cv_agg's rmse: 3.62792 + 0.117822
# [1400]	cv_agg's rmse: 3.62824 + 0.11769
# [1600]	cv_agg's rmse: 3.62872 + 0.117932

# %%
print('best num: ', len(cv_score['rmse-mean']), '\nbest score:', cv_score['rmse-mean'][-1])
# Out:
# best num:  1091
# best score: 3.6274665173050904

# %%
clf = lgb.train(rg_param, tr_data, 2000, valid_sets=(tr_data), verbose_eval=200)
# Out:
# [200]	training's rmse: 3.48668
# [400]	training's rmse: 3.36957
# [600]	training's rmse: 3.29144
# [800]	training's rmse: 3.22896
# [1000]	training's rmse: 3.17446
# [1200]	training's rmse: 3.12357
# [1400]	training's rmse: 3.07796
# [1600]	training's rmse: 3.03459
# [1800]	training's rmse: 2.99455
# [2000]	training's rmse: 2.95492

# %%
pred = clf.predict(X_va, num_iteration=clf.best_iteration)

# %%
get_lb(pred)
# Out:
# 3.7055297665571927

# %%
y_va_sort.head()
# Out:
#           target  outlier  pred_prob
# 25347 -33.219281        1   0.861653
# 92357  -0.428425        0   0.837727
# 82035  -0.043868        0   0.837408
# 94554  -1.425834        0   0.834460
# 56803   2.033892        0   0.833689

# %% [markdown]
# #### let's see top20/50 stratory

# %%
pred_df = y_va.copy()
pred_df['pred_target'] = pred

# %%
pred_df['pred_prob'] = prob

# %%
pred_df.sort_values('pred_prob', ascending=False).head(20)
# Out:
#            target  outlier  pred_target  pred_prob
# 25347  -33.219281        1   -24.386823   0.861653
# 92357   -0.428425        0   -14.233854   0.837727
# 82035   -0.043868        0   -15.332589   0.837408
# 94554   -1.425834        0   -24.055389   0.834460
# 56803    2.033892        0   -14.757560   0.833689
# 42753  -33.219281        1   -21.508205   0.832976
# 7071    -0.902819        0   -17.189649   0.829327
# 121556  -0.330013        0   -16.315167   0.828763
# 116144  -1.170125        0   -14.754357   0.828182
# 83617   -1.017764        0   -16.822752   0.826837
# 175726 -33.219281        1   -18.449574   0.825809
# 120610   0.001677        0   -16.738243   0.823772
# 15933    0.204692        0   -16.931079   0.818707
# 128262 -33.219281        1   -15.259922   0.817555
# 12602  -33.219281        1   -18.174409   0.815579
# 33257    1.948552        0    -9.858794   0.815216
# 179088 -33.219281        1   -11.016901   0.815155
# 135378 -33.219281        1   -11.684230   0.815002
# 83942  -33.219281        1   -14.564285   0.812337
# 102057   0.390960        0   -11.274019   0.812302
