# %% [markdown]
# **FEEL FREE TO UPVOTE**  （＾ｖ＾）

# %%
#
#目前最好的结果v12，使用三个模型分别预测，取得了3.684的成绩
#分类预测
#v20提交成绩得到了3.688， cv 成绩3.6519
#使用authorized_flag 进行特征分别处理,收到了奇效
#使用countVectorizer 对类别变量进行编码，内存存在压力

# %%
import numpy as np
import pandas as pd
import datetime
import gc
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold,KFold
from sklearn.metrics import mean_squared_error,log_loss
import warnings
import time
warnings.filterwarnings('ignore')
np.random.seed(4950)

# %%
# import os
# os.listdir('../input/elosinglemodel0105/')

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')
df_hist_trans = pd.read_csv('C:/Users/user/Documents/Salamat/ELO/historical_transactions.csv')
df_new_merchant_trans = pd.read_csv('C:/Users/user/Documents/Salamat/ELO/new_merchant_transactions.csv')

# %%
df_hist_trans = reduce_mem_usage(df_hist_trans)
df_new_merchant_trans = reduce_mem_usage(df_new_merchant_trans)
# Out:
# Mem. usage decreased to 1749.11 Mb (43.7% reduction)
# Mem. usage decreased to 114.20 Mb (45.5% reduction)

# %%
df_hist_trans.purchase_date=pd.to_datetime(df_hist_trans.purchase_date)
pur_date=df_hist_trans[df_hist_trans.month_lag==0].groupby('card_id').purchase_date.max()
card_id_nan_unique=df_hist_trans[df_hist_trans.card_id.isin(pur_date.index)==False].card_id.unique()
df=pd.DataFrame(card_id_nan_unique)
df['month_lag_date']=pd.to_datetime('2018-02') # Seetting all nan values to 2018 Feb
df.set_index(0,inplace=True)
new_map=df.month_lag_date
method=pur_date.append(new_map)
del df,pur_date
gc.collect()
time.sleep(5)

# %%
df_train.dtypes
# Out:
# first_active_month     object
# card_id                object
# feature_1               int64
# feature_2               int64
# feature_3               int64
# target                float64
# dtype: object

# %%
df_train['outliers'] = 0
df_train.loc[df_train['target'] < -30, 'outliers'] = 1

# %%
for df in [df_hist_trans,df_new_merchant_trans]:
#     df['category_2'].fillna(1.0,inplace=True)
#     df['category_3'].fillna('A',inplace=True)
#     df['merchant_id'].fillna('M_ID_00a6ca8a8a',inplace=True)
    #修改特征
    df['category_2'].fillna(-1,inplace=True)
    df['category_3'].fillna('other',inplace=True)
    df['merchant_id'].fillna('other',inplace=True)
#     df.loc[df['installments'].isin([999,-1]),'installments'] = 0

# %%
def get_new_columns(name,aggs):
    #for for 写法 nice
    return [name + '_' + k + '_' + agg for k in aggs.keys() for agg in aggs[k]]

# %%
for df in [df_hist_trans,df_new_merchant_trans]:
    df['purchase_date'] = pd.to_datetime(df['purchase_date'])
    df['year'] = df['purchase_date'].dt.year
    df['weekofyear'] = df['purchase_date'].dt.weekofyear
    df['month'] = df['purchase_date'].dt.month
    df['dayofweek'] = df['purchase_date'].dt.dayofweek
    df['weekend'] = (df.purchase_date.dt.weekday >=5).astype(int)
    df['hour'] = df['purchase_date'].dt.hour
    df['authorized_flag'] = df['authorized_flag'].map({'Y':1, 'N':0})
    df['category_1'] = df['category_1'].map({'Y':1, 'N':0}) 
    #https://www.kaggle.com/c/elo-merchant-category-recommendation/discussion/73244
    df['month_diff'] = ((datetime.datetime(2018,6,1) - df['purchase_date']).dt.days)//30
    df['month_diff'] += df['month_lag']

# %%
#因为根据auth_flag 将特征分成了两部分，这里聚合一个全局的auth_flag 特征
aggs = {}
aggs['purchase_amount'] = ['sum']
# aggs['installments'] = ['sum','max','min','mean','var','median']
aggs['authorized_flag'] = ['sum', 'mean','std']
aggs['card_id'] = ['size']
auth_flag = df_hist_trans.groupby(['card_id']).agg(aggs)
auth_flag.columns = get_new_columns('auth_flag',aggs)
auth_flag.reset_index(inplace=True)
df_train = df_train.merge(auth_flag,on='card_id',how='left')
df_test = df_test.merge(auth_flag,on='card_id',how='left')
del auth_flag
gc.collect()
# Out:
# 89

# %%
#对 authorized_flag进行结果编码
aggs = {}
for col in ['category_2','category_3','state_id','subsector_id','merchant_category_id','city_id']:
    df_hist_trans[col+'_auth_mean'] = df_hist_trans.groupby([col])['authorized_flag'].transform('mean')
    df_hist_trans[col+'_auth_sum'] = df_hist_trans.groupby([col])['authorized_flag'].transform('sum') 
    aggs[col+'_auth_mean'] = ['mean']
    aggs[col+'_auth_sum'] = ['sum'] 
auth_encoder = df_hist_trans.groupby(['card_id']).agg(aggs)
auth_encoder.columns = get_new_columns('auth_encoder',aggs)
auth_encoder.reset_index(inplace=True)
df_train = df_train.merge(auth_encoder,on='card_id',how='left')
df_test = df_test.merge(auth_encoder,on='card_id',how='left')
del auth_encoder
gc.collect()
# Out:
# 35

# %%
def aggregate_per_month(prefix,history,agg_func):
    grouped = history.groupby(['card_id', 'month_lag'])
    intermediate_group = grouped.agg(agg_func)
    intermediate_group.columns = [prefix + '_'.join(col).strip() for col in intermediate_group.columns.values]
    intermediate_group.reset_index(inplace=True)

    final_group = intermediate_group.groupby('card_id').agg(['mean', 'std'])
    final_group.columns = [prefix + '_'.join(col).strip() for col in final_group.columns.values]
    final_group.reset_index(inplace=True) 
    return final_group

# %%
#对授权码 进行按月聚合
agg_func = {'authorized_flag': [ 'sum', 'mean','median']}
final_group =  aggregate_per_month('agg_per_month_total',df_hist_trans,agg_func) 
df_train = df_train.merge(final_group,on='card_id',how='left')
df_test = df_test.merge(final_group,on='card_id',how='left')
del final_group

# %%
authorized_transactions = df_hist_trans[df_hist_trans['authorized_flag'] == 1]
df_hist_trans = df_hist_trans[df_hist_trans['authorized_flag'] == 0]

# %%
df_hist_trans.shape
# Out:
# (2516909, 33)

# %%
agg_func = {'purchase_amount': [ 'sum', 'mean', 'min', 'max', 'std']}
final_group =  aggregate_per_month('agg_per_month_auth',authorized_transactions,agg_func) 
df_train = df_train.merge(final_group,on='card_id',how='left')
df_test = df_test.merge(final_group,on='card_id',how='left')
del final_group
final_group =  aggregate_per_month('agg_per_month_hist',df_hist_trans,agg_func) 
df_train = df_train.merge(final_group,on='card_id',how='left')
df_test = df_test.merge(final_group,on='card_id',how='left')
del final_group
final_group =  aggregate_per_month('agg_per_month_hist_new',df_new_merchant_trans,agg_func) 
df_train = df_train.merge(final_group,on='card_id',how='left')
df_test = df_test.merge(final_group,on='card_id',how='left')
del final_group
gc.collect()
# Out:
# 71

# %%
i = 0
for df in [authorized_transactions,df_hist_trans]:
    aggs = {}
    for col in ['month','hour','weekofyear','dayofweek','year','subsector_id','merchant_id','merchant_category_id',
                'state_id','city_id']:
        aggs[col] = ['nunique']

    aggs['purchase_amount'] = ['sum','max','min','mean','var','median']
    aggs['installments'] = ['sum','max','min','mean','var','median']
    aggs['purchase_date'] = ['max','min']
    aggs['month_lag'] = ['max','min','mean','var','median']
    aggs['month_diff'] = ['mean','median']
#     aggs['authorized_flag'] = ['sum', 'mean','median']
    aggs['weekend'] = ['sum', 'mean']
    aggs['category_1'] = ['sum', 'mean']
    aggs['card_id'] = ['size']
    #产生交叉特征，内存有问题
    features = ['category_2','category_3','state_id','subsector_id','merchant_category_id','city_id'
               ,'merchant_id']
#     for coli in ['category_2','category_3','state_id','subsector_id','merchant_category_id','city_id']:
#         for colj in ['category_2','category_3','state_id','subsector_id','merchant_category_id','city_id']:
#             df[coli + colj] = df[coli].astype(str) + df[colj].astype(str)
#             features.append(coli + colj)
    for col in features:
        df[col+'_mean'] = df.groupby([col])['purchase_amount'].transform('mean')
        df[col+'_sum'] = df.groupby([col])['purchase_amount'].transform('sum') 
        aggs[col+'_mean'] = ['mean']
        aggs[col+'_sum'] = ['sum'] 
    if i == 0:
        prefix = 'auth_hist'
    else:
        prefix = 'hist'
    new_columns = get_new_columns(prefix,aggs)
    i += 1
    # df_hist_trans.sort_values(['card_id','purchase_date'],inplace = True)

    df_hist_trans_group = df.groupby('card_id').agg(aggs)
    df_hist_trans_group.columns = new_columns
    df_hist_trans_group.reset_index(drop=False,inplace=True)
    df_hist_trans_group[prefix + '_purchase_date_diff'] = (df_hist_trans_group[prefix + '_purchase_date_max'] - df_hist_trans_group[prefix + '_purchase_date_min']).dt.days
    df_hist_trans_group[prefix + '_purchase_date_average'] = df_hist_trans_group[prefix + '_purchase_date_diff']/df_hist_trans_group[prefix + '_card_id_size']
    #df_hist_trans_group[prefix + '_purchase_date_uptonow'] = (df_hist_trans_group['card_id'].map(method) - df_hist_trans_group[prefix + '_purchase_date_max']).dt.days
   
    df_hist_trans_group[prefix + '_purchase_date_uptonow'] = (df_hist_trans_group['card_id'].map(method) - df_hist_trans_group[prefix + '_purchase_date_min']).dt.days
    
    ### This is old feature but I change the name to [prefix + '_first_purchase'] from [prefix + '_purchase_date_uptonow']
    ### since it makes more sense. Number of days for the last purchase from month_lag_0

    df_hist_trans_group[prefix + '_first_purchase'] = (df_hist_trans_group['card_id'].map(method) - df_hist_trans_group[prefix + '_purchase_date_max']).dt.days   
#下面这个特征考虑了：有的人可能购买频率较低，但是还是忠实粉丝的情况
#     df_hist_trans_group[prefix + '_purchase_date_uptonow_ave'] =  df_hist_trans_group[prefix + '_purchase_date_uptonow']/df_hist_trans_group[prefix + '_purchase_date_average']

    #每一个card中未授权消费次数
#     df_hist_trans_group[prefix + '_unauthorized_number'] = df_hist_trans_group[prefix + '_card_id_size'] - df_hist_trans_group[prefix + '_authorized_flag_sum']
    #最近活跃时间，确实是一个强特征，感觉可以再挖出来几个特征，比如最近5次消费时间，最近10次消费时间，如果值比较小，说明最近很活跃
    #没有效果
    # grouped =  df_hist_trans.groupby('card_id')['purchase_date']
    # df_hist_trans_group['hist_purchase_5thdate_uptonow'] =  (datetime.datetime.today() -grouped.shift(5)).dt.days
    # df_hist_trans_group['hist_purchase_3thdate_uptonow'] =  (datetime.datetime.today() -grouped.shift(3)).dt.days
    # df_hist_trans_group['hist_purchase_10thdate_uptonow'] =  (datetime.datetime.today() -grouped.shift(10)).dt.days
    df_train = df_train.merge(df_hist_trans_group,on='card_id',how='left')
    df_test = df_test.merge(df_hist_trans_group,on='card_id',how='left')
    del df_hist_trans_group
    time.sleep(5)
    gc.collect()
    del df;gc.collect()
    time.sleep(5)

# %%
aggs = {}
#添加特征
for col in ['month','hour','weekofyear','dayofweek','year','subsector_id','merchant_id','merchant_category_id',
            'state_id','city_id']:
    aggs[col] = ['nunique']
    
aggs['purchase_amount'] = ['sum','max','min','mean','var','median']
aggs['installments'] = ['sum','max','min','mean','var','median']
aggs['purchase_date'] = ['max','min']
aggs['month_lag'] = ['max','min','mean','var','median']
aggs['month_diff'] = ['mean','median']
aggs['weekend'] = ['sum', 'mean']
aggs['authorized_flag'] = ['sum', 'mean','median']
aggs['category_1'] = ['sum', 'mean']
aggs['card_id'] = ['size']

#添加特征   
features = ['category_2','category_3','state_id','subsector_id','merchant_category_id','city_id'
               ,'merchant_id']
#产生交叉特征，内存有问题
# for coli in ['category_2','category_3','state_id','subsector_id','merchant_category_id','city_id']:
#     for colj in ['category_2','category_3','state_id','subsector_id','merchant_category_id','city_id']:
#         df_new_merchant_trans[coli + colj] = df_new_merchant_trans[coli].astype(str) + df_new_merchant_trans[colj].astype(str)
#         features.append(coli + colj)
for col in features:
    df_new_merchant_trans[col+'_mean'] = df_new_merchant_trans.groupby([col])['purchase_amount'].transform('mean')
    df_new_merchant_trans[col+'_sum'] = df_new_merchant_trans.groupby([col])['purchase_amount'].transform('sum')
    aggs[col+'_mean'] = ['mean']
    aggs[col+'_sum'] = ['sum']
new_columns = get_new_columns('new_hist',aggs)
# df_new_merchant_trans.sort_values(['card_id','purchase_date'],inplace = True)
df_hist_trans_group = df_new_merchant_trans.groupby('card_id').agg(aggs)
df_hist_trans_group.columns = new_columns
df_hist_trans_group.reset_index(drop=False,inplace=True)
df_hist_trans_group['new_hist_purchase_date_diff'] = (df_hist_trans_group['new_hist_purchase_date_max'] - df_hist_trans_group['new_hist_purchase_date_min']).dt.days
df_hist_trans_group['new_hist_purchase_date_average'] = df_hist_trans_group['new_hist_purchase_date_diff']/df_hist_trans_group['new_hist_card_id_size']
#df_hist_trans_group['new_hist_purchase_date_uptonow'] = (df_hist_trans_group['card_id'].map(method) - df_hist_trans_group['new_hist_purchase_date_max']).dt.days
df_hist_trans_group['new_hist_purchase_date_uptonow'] = (df_hist_trans_group['card_id'].map(method) - df_hist_trans_group['new_hist_purchase_date_max']).dt.days

# new feature for the first purchase.This means total number of days from month_lag_0 to first purchase.
df_hist_trans_group['new_hist_first_purchase'] = (df_hist_trans_group['card_id'].map(method) - df_hist_trans_group['new_hist_purchase_date_min']).dt.days
#下面这个特征考虑了：有的人可能购买频率较低，但是还是忠实粉丝的情况
# df_hist_trans_group['new_hist_purchase_date_uptonow_ave'] =  df_hist_trans_group['new_hist_purchase_date_uptonow']/df_hist_trans_group['new_hist_purchase_date_average']

# grouped = df_new_merchant_trans.groupby('card_id')['purchase_date']
# df_hist_trans_group['new_hist_purchase_5thdate_uptonow'] =  (datetime.datetime.today() - grouped.shift(5)).dt.days
# df_hist_trans_group['new_hist_purchase_3thdate_uptonow'] =  (datetime.datetime.today() - grouped.shift(3)).dt.days
# df_hist_trans_group['new_hist_purchase_10thdate_uptonow'] =  (datetime.datetime.today() - grouped.shift(10)).dt.days

df_train = df_train.merge(df_hist_trans_group,on='card_id',how='left')
df_test = df_test.merge(df_hist_trans_group,on='card_id',how='left')
del df_hist_trans_group
gc.collect()
del df_new_merchant_trans
gc.collect()
time.sleep(5)

# %%
for df in [df_train,df_test]:
    df['first_active_month'] = pd.to_datetime(df['first_active_month'])
    df['dayofweek'] = df['first_active_month'].dt.dayofweek
    df['weekofyear'] = df['first_active_month'].dt.weekofyear
    df['month'] = df['first_active_month'].dt.month
    df['elapsed_time'] = (df['card_id'].map(method) - df['first_active_month']).dt.days
    df['hist_first_buy'] = (df['hist_purchase_date_min'] - df['first_active_month']).dt.days
    df['new_hist_first_buy'] = (df['new_hist_purchase_date_min'] - df['first_active_month']).dt.days
    #添加特征
    df['auth_hist_first_buy'] = (df['auth_hist_purchase_date_min'] - df['first_active_month']).dt.days
    #修改特征
    for f in ['hist_purchase_date_max','hist_purchase_date_min','new_hist_purchase_date_max',\
                     'new_hist_purchase_date_min','auth_hist_purchase_date_max','auth_hist_purchase_date_min']:
        df[f] = df[f].astype(np.int64) * 1e-9
    for f in ['auth_encoder_category_2_auth_sum_sum','auth_encoder_category_3_auth_sum_sum',
            'auth_encoder_state_id_auth_sum_sum','auth_encoder_subsector_id_auth_sum_sum',
            'auth_encoder_merchant_category_id_auth_sum_sum','auth_encoder_city_id_auth_sum_sum']:
        df[f] = df[f].astype(np.int64) * 1e-9
    #上面auth_flag已经聚合过了card_id_size ,purchase_amount
#     df['card_id_total'] = df['new_hist_card_id_size']+df['hist_card_id_size']  + df['auth_hist_card_id_size']
#     df['purchase_amount_total'] = df['new_hist_purchase_amount_sum']+df['hist_purchase_amount_sum']+df['auth_hist_purchase_amount_sum']
#添加特征
#下面这个特征对于识别异常点有一定帮助，但是训练model_without_outliers的时候需要删除这几个特征。
for f in ['feature_1','feature_2','feature_3']:
    order_label1 = df_train.groupby([f])['outliers'].mean()
    df_train[f+'_outliers_mean'] = df_train[f].map(order_label1)
    df_test[f+'_outliers_mean'] = df_test[f].map(order_label1)
    
    order_label2 = df_train.groupby([f])['outliers'].sum()
    df_train[f+'_outliers_sum'] = df_train[f].map(order_label2)
    df_test[f+'_outliers_sum'] = df_test[f].map(order_label2)
    
# get_dummies 似乎有一点点不良影响
# df_train = pd.get_dummies(df_train,columns =['feature_1','feature_2'])
# df_test = pd.get_dummies(df_test,columns =['feature_1','feature_2'])

# %%
#首次购买的时间居然早于首次激活的时间，进行调整
df_train.loc[df_train['auth_hist_first_buy'] < 0, 'auth_hist_first_buy'] = -1
df_train.loc[df_train['hist_first_buy'] < 0, 'hist_first_buy'] = -1
df_train.head()
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0         2017-06-01  C_ID_92a2005557          5          2          1
# 1         2017-01-01  C_ID_3d0044924f          4          1          0
# 2         2016-08-01  C_ID_d639edf6cd          2          2          0
# 3         2017-09-01  C_ID_186d6a6901          4          3          0
# 4         2017-11-01  C_ID_cdbd2c0db2          1          3          0
#
#      target  outliers  auth_flag_purchase_amount_sum  \
# 0 -0.820283         0                    -165.968735
# 1  0.392913         0                    -210.006332
# 2  0.688056         0                     -29.167391
# 3  0.142495         0                     -49.491364
# 4 -0.159749         0                     -48.687656
#
#    auth_flag_authorized_flag_sum  auth_flag_authorized_flag_mean  \
# 0                            247                        0.950000
# 1                            339                        0.968571
# 2                             41                        0.953488
# 3                             77                        1.000000
# 4                            128                        0.962406
#
#             ...            elapsed_time  hist_first_buy  new_hist_first_buy  \
# 0           ...                     269            44.0               277.0
# 1           ...                     395            61.0               396.0
# 2           ...                     575           206.0               635.0
# 3           ...                     180             NaN               187.0
# 4           ...                     119            80.0               121.0
#
#    auth_hist_first_buy  feature_1_outliers_mean  feature_1_outliers_sum  \
# 0                   26                 0.013145                     534
# 1                    5                 0.010712                     213
# 2                  163                 0.010610                     592
# 3                   25                 0.010712                     213
# 4                   11                 0.008058                      97
#
#    feature_2_outliers_mean  feature_2_outliers_sum  feature_3_outliers_mean  \
# 0                 0.008752                     655                 0.011428
# 1                 0.011385                    1016                 0.010283
# 2                 0.008752                     655                 0.010283
# 3                 0.014166                     536                 0.010283
# 4                 0.014166                     536                 0.010283
#
#    feature_3_outliers_sum
# 0                    1305
# 1                     902
# 2                     902
# 3                     902
# 4                     902
#
# [5 rows x 246 columns]

# %%
# df_train_outliers = pd.read_csv('../input/elooutlier/outliers_train_output.txt',names = ['score'])
# df_test_outliers = pd.read_csv('../input/elooutlier/outliers_test_output.txt',names = ['score'])
# df_train['outliers_score'] = df_train_outliers['score'].values
# df_test['outliers_score'] = df_test_outliers['score'].values
# df_train.head()

# %%
df_test.head()
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0         2017-04-01  C_ID_0ab67a22ab          3          3          1
# 1         2017-01-01  C_ID_130fd0cbdd          2          3          0
# 2         2017-08-01  C_ID_b709037bc5          5          1          1
# 3         2017-12-01  C_ID_d27d835a9f          2          1          0
# 4         2015-12-01  C_ID_2b5e3df5c2          5          1          1
#
#    auth_flag_purchase_amount_sum  auth_flag_authorized_flag_sum  \
# 0                     -40.733734                             44
# 1                     -49.136513                             77
# 2                       4.528841                              9
# 3                     -13.690715                             26
# 4                      25.139385                             87
#
#    auth_flag_authorized_flag_mean  auth_flag_authorized_flag_std  \
# 0                        0.647059                       0.481438
# 1                        0.987179                       0.113228
# 2                        0.692308                       0.480384
# 3                        1.000000                       0.000000
# 4                        0.790909                       0.408521
#
#    auth_flag_card_id_size           ...            elapsed_time  \
# 0                      68           ...                   272.0
# 1                      78           ...                   413.0
# 2                      13           ...                   185.0
# 3                      26           ...                    81.0
# 4                     110           ...                   819.0
#
#    hist_first_buy  new_hist_first_buy  auth_hist_first_buy  \
# 0            26.0               308.0                  3.0
# 1           125.0               426.0                 12.0
# 2           163.0               212.0                 24.0
# 3             NaN                93.0                  3.0
# 4           399.0               824.0                400.0
#
#    feature_1_outliers_mean  feature_1_outliers_sum  feature_2_outliers_mean  \
# 0                 0.010479                     771                 0.014166
# 1                 0.010610                     592                 0.014166
# 2                 0.013145                     534                 0.011385
# 3                 0.010610                     592                 0.011385
# 4                 0.013145                     534                 0.011385
#
#    feature_2_outliers_sum  feature_3_outliers_mean  feature_3_outliers_sum
# 0                     536                 0.011428                    1305
# 1                     536                 0.010283                     902
# 2                    1016                 0.011428                    1305
# 3                    1016                 0.010283                     902
# 4                    1016                 0.011428                    1305
#
# [5 rows x 244 columns]

# %%
exclude_features = []
exclude_features += ['card_id', 'first_active_month','target','outliers']
df_train_columns = [c for c in df_train.columns if c not in exclude_features ]
categorical_feats = [c for c in df_train_columns if 'feature_' in c]
target = df_train['target']

# %%
print(categorical_feats)
df_train.columns
# Out:
# ['feature_1', 'feature_2', 'feature_3', 'feature_1_outliers_mean', 'feature_1_outliers_sum', 'feature_2_outliers_mean', 'feature_2_outliers_sum', 'feature_3_outliers_mean', 'feature_3_outliers_sum']
# Index(['first_active_month', 'card_id', 'feature_1', 'feature_2', 'feature_3',
#        'target', 'outliers', 'auth_flag_purchase_amount_sum',
#        'auth_flag_authorized_flag_sum', 'auth_flag_authorized_flag_mean',
#        ...
#        'elapsed_time', 'hist_first_buy', 'new_hist_first_buy',
#        'auth_hist_first_buy', 'feature_1_outliers_mean',
#        'feature_1_outliers_sum', 'feature_2_outliers_mean',
#        'feature_2_outliers_sum', 'feature_3_outliers_mean',
#        'feature_3_outliers_sum'],
#       dtype='object', length=246)

# %%
#训练分类模型
param = {'num_leaves': 31,
         'min_data_in_leaf': 150, 
         'objective':'binary',
         'max_depth': 6,
         'learning_rate': 0.01,
         "boosting": "rf",
         "feature_fraction": 0.9,
         "bagging_freq": 1,
         "bagging_fraction": 0.9 ,
         "bagging_seed": 11,
         "metric": 'binary_logloss',
         'scale_pos_weight':15,
         "lambda_l1": 0.1,
         "verbosity": -1,
         "random_state": 2333}
folds = StratifiedKFold(n_splits=10, shuffle=True, random_state=4950)
oof = np.zeros(len(df_train))
predictions = np.zeros(len(df_test))
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train,df_train['outliers'].values)):
    print("fold {}".format(fold_))
    trn_data = lgb.Dataset(df_train.iloc[trn_idx][df_train_columns], label=df_train['outliers'].iloc[trn_idx], categorical_feature=categorical_feats)
    val_data = lgb.Dataset(df_train.iloc[val_idx][df_train_columns], label=df_train['outliers'].iloc[val_idx], categorical_feature=categorical_feats)

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 600)
    oof[val_idx] = clf.predict(df_train.iloc[val_idx][df_train_columns], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = df_train_columns
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(df_test[df_train_columns], num_iteration=clf.best_iteration) / folds.n_splits

print("CV score: {:<8.5f}".format(log_loss(df_train['outliers'], oof)))
# Out:
# fold 0
# Training until validation scores don't improve for 600 rounds.
# [100]	training's binary_logloss: 4.33645	valid_1's binary_logloss: 4.23824
# [200]	training's binary_logloss: 4.32963	valid_1's binary_logloss: 4.22964
# [300]	training's binary_logloss: 4.33178	valid_1's binary_logloss: 4.23055
# [400]	training's binary_logloss: 4.33449	valid_1's binary_logloss: 4.23369
# [500]	training's binary_logloss: 4.33052	valid_1's binary_logloss: 4.23004
# [600]	training's binary_logloss: 4.32334	valid_1's binary_logloss: 4.22338
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 4.06919	valid_1's binary_logloss: 3.98733
# fold 1
# Training until validation scores don't improve for 600 rounds.
# [100]	training's binary_logloss: 4.23335	valid_1's binary_logloss: 4.32189
# [200]	training's binary_logloss: 4.23052	valid_1's binary_logloss: 4.31597
# [300]	training's binary_logloss: 4.22913	valid_1's binary_logloss: 4.3154
# [400]	training's binary_logloss: 4.22703	valid_1's binary_logloss: 4.3129
# [500]	training's binary_logloss: 4.22447	valid_1's binary_logloss: 4.31104
# [600]	training's binary_logloss: 4.22247	valid_1's binary_logloss: 4.30875
# Early stopping, best iteration is:
# [7]	training's binary_logloss: 4.22084	valid_1's binary_logloss: 4.30413
# fold 2
# Training until validation scores don't improve for 600 rounds.
# [100]	training's binary_logloss: 4.0857	valid_1's binary_logloss: 4.18478
# [200]	training's binary_logloss: 4.07987	valid_1's binary_logloss: 4.17853
# [300]	training's binary_logloss: 4.07673	valid_1's binary_logloss: 4.17478
# [400]	training's binary_logloss: 4.07389	valid_1's binary_logloss: 4.17078
# [500]	training's binary_logloss: 4.0796	valid_1's binary_logloss: 4.17713
# [600]	training's binary_logloss: 4.07923	valid_1's binary_logloss: 4.17722
# Early stopping, best iteration is:
# [19]	training's binary_logloss: 4.04507	valid_1's binary_logloss: 4.13711
# fold 3
# Training until validation scores don't improve for 600 rounds.
# [100]	training's binary_logloss: 4.25232	valid_1's binary_logloss: 4.2515
# [200]	training's binary_logloss: 4.23991	valid_1's binary_logloss: 4.23696
# [300]	training's binary_logloss: 4.24081	valid_1's binary_logloss: 4.23855
# [400]	training's binary_logloss: 4.2411	valid_1's binary_logloss: 4.23866
# [500]	training's binary_logloss: 4.24448	valid_1's binary_logloss: 4.24188
# [600]	training's binary_logloss: 4.24269	valid_1's binary_logloss: 4.23993
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 4.21926	valid_1's binary_logloss: 4.19366
# fold 4
# Training until validation scores don't improve for 600 rounds.
# [100]	training's binary_logloss: 4.23949	valid_1's binary_logloss: 4.35337
# [200]	training's binary_logloss: 4.22659	valid_1's binary_logloss: 4.33645
# [300]	training's binary_logloss: 4.22584	valid_1's binary_logloss: 4.33533
# [400]	training's binary_logloss: 4.2291	valid_1's binary_logloss: 4.33926
# [500]	training's binary_logloss: 4.23036	valid_1's binary_logloss: 4.34035
# [600]	training's binary_logloss: 4.22809	valid_1's binary_logloss: 4.33833
# [700]	training's binary_logloss: 4.22664	valid_1's binary_logloss: 4.33724
# [800]	training's binary_logloss: 4.22723	valid_1's binary_logloss: 4.33748
# Early stopping, best iteration is:
# [269]	training's binary_logloss: 4.22255	valid_1's binary_logloss: 4.33202
# fold 5
# Training until validation scores don't improve for 600 rounds.
# [100]	training's binary_logloss: 4.24004	valid_1's binary_logloss: 4.31841
# [200]	training's binary_logloss: 4.24513	valid_1's binary_logloss: 4.32677
# [300]	training's binary_logloss: 4.23601	valid_1's binary_logloss: 4.3153
# [400]	training's binary_logloss: 4.23384	valid_1's binary_logloss: 4.31343
# [500]	training's binary_logloss: 4.23133	valid_1's binary_logloss: 4.31081
# [600]	training's binary_logloss: 4.23449	valid_1's binary_logloss: 4.3138
# Early stopping, best iteration is:
# [10]	training's binary_logloss: 4.20432	valid_1's binary_logloss: 4.28057
# fold 6
# Training until validation scores don't improve for 600 rounds.
# [100]	training's binary_logloss: 4.37772	valid_1's binary_logloss: 4.2267
# [200]	training's binary_logloss: 4.37738	valid_1's binary_logloss: 4.22421
# [300]	training's binary_logloss: 4.37975	valid_1's binary_logloss: 4.2275
# [400]	training's binary_logloss: 4.38748	valid_1's binary_logloss: 4.23708
# [500]	training's binary_logloss: 4.38481	valid_1's binary_logloss: 4.23347
# [600]	training's binary_logloss: 4.38354	valid_1's binary_logloss: 4.23283
# Early stopping, best iteration is:
# [27]	training's binary_logloss: 4.35197	valid_1's binary_logloss: 4.20854
# fold 7
# Training until validation scores don't improve for 600 rounds.
# [100]	training's binary_logloss: 4.10775	valid_1's binary_logloss: 4.18269
# [200]	training's binary_logloss: 4.10749	valid_1's binary_logloss: 4.17892
# [300]	training's binary_logloss: 4.10978	valid_1's binary_logloss: 4.18132
# [400]	training's binary_logloss: 4.11446	valid_1's binary_logloss: 4.18628
# [500]	training's binary_logloss: 4.1135	valid_1's binary_logloss: 4.1853
# [600]	training's binary_logloss: 4.11293	valid_1's binary_logloss: 4.18402
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 4.00138	valid_1's binary_logloss: 4.06992
# fold 8
# Training until validation scores don't improve for 600 rounds.
# [100]	training's binary_logloss: 4.19348	valid_1's binary_logloss: 4.17073
# [200]	training's binary_logloss: 4.20609	valid_1's binary_logloss: 4.18196
# [300]	training's binary_logloss: 4.21079	valid_1's binary_logloss: 4.18327
# [400]	training's binary_logloss: 4.21448	valid_1's binary_logloss: 4.18748
# [500]	training's binary_logloss: 4.21277	valid_1's binary_logloss: 4.18668
# [600]	training's binary_logloss: 4.21283	valid_1's binary_logloss: 4.18733
# Early stopping, best iteration is:
# [4]	training's binary_logloss: 4.17822	valid_1's binary_logloss: 4.15156
# fold 9
# Training until validation scores don't improve for 600 rounds.
# [100]	training's binary_logloss: 4.25877	valid_1's binary_logloss: 4.27697
# [200]	training's binary_logloss: 4.24713	valid_1's binary_logloss: 4.26026
# [300]	training's binary_logloss: 4.24699	valid_1's binary_logloss: 4.26178
# [400]	training's binary_logloss: 4.25196	valid_1's binary_logloss: 4.26639
# [500]	training's binary_logloss: 4.25229	valid_1's binary_logloss: 4.2671
# [600]	training's binary_logloss: 4.25008	valid_1's binary_logloss: 4.26598
# Early stopping, best iteration is:
# [16]	training's binary_logloss: 4.22217	valid_1's binary_logloss: 4.2495
# CV score: 4.19147

# %%
# 计算结果，对于训练集，一个比较合适的召回率，似乎需要12w 训练样本，对于测试集，我们选择6w作为潜在的异常点吧。
# 实验结果提升较小，可能测试集中异常点比例较低
df_outlier_prob = pd.DataFrame({"card_id":df_train["card_id"].values})
df_outlier_prob["target"] = oof
outlier_id = pd.DataFrame(df_outlier_prob.sort_values(by='target',ascending = False).head(10000)['card_id'])
for k in range(10000,200000,10000):
    outlier_id = pd.DataFrame(df_outlier_prob.sort_values(by='target',ascending = False).head(k)['card_id'])
    out = set(outlier_id['card_id'].values)
    i = 0
    for id in df_train[df_train['outliers'] == 1]['card_id'].values:
        if id in out:
            i += 1
    print(i,k)
# Out:
# 1123 10000
# 1519 20000
# 1680 30000
# 1808 40000
# 1883 50000
# 1936 60000
# 1976 70000
# 2022 80000
# 2067 90000
# 2092 100000
# 2110 110000
# 2129 120000
# 2148 130000
# 2162 140000
# 2167 150000
# 2172 160000
# 2178 170000
# 2188 180000
# 2198 190000

# %%
2207 / 201917
# Out:
# 0.010930233709890698

# %%
### 'target' is the probability of whether an observation is an outlier
df_outlier_prob = pd.DataFrame({"card_id":df_test["card_id"].values})
df_outlier_prob["target"] = predictions
# In case missing some predictable outlier, we choose top 25000 with highest outliers likelyhood.
outlier_id = pd.DataFrame(df_outlier_prob.sort_values(by='target',ascending = False).head(18000)['card_id'])

# %%
df_outlier_prob.head()
# Out:
#            card_id    target
# 0  C_ID_0ab67a22ab  1.000000
# 1  C_ID_130fd0cbdd  0.016027
# 2  C_ID_b709037bc5  0.891494
# 3  C_ID_d27d835a9f  0.014020
# 4  C_ID_2b5e3df5c2  0.014697

# %% [markdown]
# # Seperate the train and test data into three part ,

# %%
ratio = len(df_test) / len(df_train)
ratio
# Out:
# 0.6122466161838775

# %%
### 'target' is the probability of whether an observation is an outlier
df_outlier_prob = pd.DataFrame({"card_id":df_test["card_id"].values})
df_outlier_prob["target"] = predictions
# In case missing some predictable outlier, we choose top 25000 with highest outliers likelyhood.
outlier_id = df_outlier_prob.sort_values(by='target',ascending = False).index
test_id_part = []
# ratio = len(df_test) / len(df_train)
# 参考李胃疼的思路，这里直接预测前18000个
test_id_part.append(outlier_id[:18000])
# test_id_part.append(outlier_id[int(10000 * ratio) : int(50000 * ratio)])
test_id_part.append(outlier_id[18000:])

# %%
df_outlier_prob = pd.DataFrame({"card_id":df_train["card_id"].values})
df_outlier_prob["target"] = oof
# In case missing some predictable outlier, we choose top 25000 with highest outliers likelyhood.
outlier_id = df_outlier_prob.sort_values(by='target',ascending = False).index
train_id_part = []
train_id_part.append(outlier_id[:50000])
# train_id_part.append(outlier_id[10000:50000])
# train_id_part.append(outlier_id[20000:])
without_outliers = df_train[df_train['target'] > -33].index
train_id_part.append(without_outliers)

# %%
c = [ c for c in df_train.loc[train_id_part[1]]['target'].values if c < -33]
len(c)
# Out:
# 0

# %%
targets = []
targets.append(df_train.loc[train_id_part[0]]['target'])
targets.append(df_train.loc[train_id_part[1]]['target'])
# targets.append(df_train.loc[train_id_part[2]]['target'])

#删除异常值编码，下面是没有异常值的训练集
#下面这个特征对于识别异常点有一定帮助，但是训练model_without_outliers的时候需要删除这几个特征。
# for f in ['feature_1','feature_2','feature_3']:
#     del df_train[f + '_outliers_mean']
#     del df_train[f + '_outliers_sum']
#     del df_test[f + '_outliers_mean']
#     del df_test[f + '_outliers_sum']
# del df_train['outliers_score']
# del df_test['outliers_score']

# %%
exclude_features = []
exclude_features += ['card_id', 'first_active_month','target','outliers']
df_train_columns = [c for c in df_train.columns if c not in exclude_features ]
categorical_feats = [c for c in df_train_columns if 'feature_' in c]

# %%
param = {'num_leaves': 31,
         'min_data_in_leaf': 32, 
         'objective':'regression',
         'max_depth': -1,
         'learning_rate': 0.01,
         "min_child_samples": 20,
         "boosting": "gbdt",
         "feature_fraction": 0.9,
         "bagging_freq": 1,
         "bagging_fraction": 0.9 ,
         "bagging_seed": 42,
         "metric": 'rmse',
         "lambda_l1": 0.1,
         "verbosity": -1,
         "nthread": 4,
         "random_state": 4950}

# %%
from sklearn.model_selection import KFold
# all_train = np.zeros(len(df_train))
all_test = np.zeros(len(df_test))
for i in range(len(test_id_part)):
    folds = KFold(n_splits=10, shuffle=True, random_state=4950)
    train = df_train.loc[train_id_part[i]]
    test = df_test.loc[test_id_part[i]]
    oof = np.zeros(len(train))
    predictions = np.zeros(len(test))
    target = targets[i]
    for fold_, (trn_idx, val_idx) in enumerate(folds.split(train,target.values)):
        print("fold {}".format(fold_))
        trn_data = lgb.Dataset(train.iloc[trn_idx][df_train_columns], label=target.iloc[trn_idx], categorical_feature=categorical_feats)
        val_data = lgb.Dataset(train.iloc[val_idx][df_train_columns], label=target.iloc[val_idx], categorical_feature=categorical_feats)
#         num_round = 200
        num_round = 10000
        clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 600)
        oof[val_idx] = clf.predict(train.iloc[val_idx][df_train_columns], num_iteration=clf.best_iteration)
        predictions += clf.predict(test[df_train_columns], num_iteration=clf.best_iteration) / folds.n_splits

    print(np.sqrt(mean_squared_error(oof, target)))
#     all_train[train_id_part[i]] = oof
    all_test[test_id_part[i]] = predictions
# np.sqrt(mean_squared_error(all_train, df_train['target']))
# Out:
# fold 0
# Training until validation scores don't improve for 600 rounds.
# [100]	training's rmse: 6.28247	valid_1's rmse: 6.37663
# [200]	training's rmse: 6.09015	valid_1's rmse: 6.3166
# [300]	training's rmse: 5.95649	valid_1's rmse: 6.29562
# [400]	training's rmse: 5.85537	valid_1's rmse: 6.2819
# [500]	training's rmse: 5.77227	valid_1's rmse: 6.27359
# [600]	training's rmse: 5.69748	valid_1's rmse: 6.27103
# [700]	training's rmse: 5.6281	valid_1's rmse: 6.26704
# [800]	training's rmse: 5.56405	valid_1's rmse: 6.26661
# [900]	training's rmse: 5.50157	valid_1's rmse: 6.26592
# [1000]	training's rmse: 5.44193	valid_1's rmse: 6.26619
# [1100]	training's rmse: 5.38579	valid_1's rmse: 6.2676
# [1200]	training's rmse: 5.33118	valid_1's rmse: 6.26887
# [1300]	training's rmse: 5.27738	valid_1's rmse: 6.26964
# Early stopping, best iteration is:
# [759]	training's rmse: 5.58973	valid_1's rmse: 6.26476
# fold 1
# Training until validation scores don't improve for 600 rounds.
# [100]	training's rmse: 6.29132	valid_1's rmse: 6.2915
# [200]	training's rmse: 6.10512	valid_1's rmse: 6.23189
# [300]	training's rmse: 5.97238	valid_1's rmse: 6.20823
# [400]	training's rmse: 5.86977	valid_1's rmse: 6.19747
# [500]	training's rmse: 5.78372	valid_1's rmse: 6.19018
# [600]	training's rmse: 5.71155	valid_1's rmse: 6.187
# [700]	training's rmse: 5.642	valid_1's rmse: 6.18803
# [800]	training's rmse: 5.57929	valid_1's rmse: 6.18732
# [900]	training's rmse: 5.51863	valid_1's rmse: 6.1871
# [1000]	training's rmse: 5.45857	valid_1's rmse: 6.18886
# [1100]	training's rmse: 5.40167	valid_1's rmse: 6.18866
# [1200]	training's rmse: 5.34675	valid_1's rmse: 6.18803
# [1300]	training's rmse: 5.29306	valid_1's rmse: 6.18847
# [1400]	training's rmse: 5.23996	valid_1's rmse: 6.1903
# Early stopping, best iteration is:
# [867]	training's rmse: 5.539	valid_1's rmse: 6.18618
# fold 2
# Training until validation scores don't improve for 600 rounds.
# [100]	training's rmse: 6.25282	valid_1's rmse: 6.60678
# [200]	training's rmse: 6.06106	valid_1's rmse: 6.55536
# [300]	training's rmse: 5.92822	valid_1's rmse: 6.53977
# [400]	training's rmse: 5.82769	valid_1's rmse: 6.53273
# [500]	training's rmse: 5.74281	valid_1's rmse: 6.52998
# [600]	training's rmse: 5.66998	valid_1's rmse: 6.52827
# [700]	training's rmse: 5.60378	valid_1's rmse: 6.5296
# [800]	training's rmse: 5.53882	valid_1's rmse: 6.53359
# [900]	training's rmse: 5.47784	valid_1's rmse: 6.53331
# [1000]	training's rmse: 5.41952	valid_1's rmse: 6.53303
# [1100]	training's rmse: 5.36484	valid_1's rmse: 6.53237
# Early stopping, best iteration is:
# [585]	training's rmse: 5.67976	valid_1's rmse: 6.52748
# fold 3
# Training until validation scores don't improve for 600 rounds.
# [100]	training's rmse: 6.28901	valid_1's rmse: 6.30865
# [200]	training's rmse: 6.10107	valid_1's rmse: 6.25245
# [300]	training's rmse: 5.96927	valid_1's rmse: 6.23686
# [400]	training's rmse: 5.86859	valid_1's rmse: 6.22841
# [500]	training's rmse: 5.78289	valid_1's rmse: 6.22703
# [600]	training's rmse: 5.70949	valid_1's rmse: 6.22703
# [700]	training's rmse: 5.64157	valid_1's rmse: 6.22949
# [800]	training's rmse: 5.57961	valid_1's rmse: 6.23084
# [900]	training's rmse: 5.51849	valid_1's rmse: 6.23283
# [1000]	training's rmse: 5.45922	valid_1's rmse: 6.23572
# [1100]	training's rmse: 5.40237	valid_1's rmse: 6.23752
# Early stopping, best iteration is:
# [570]	training's rmse: 5.73075	valid_1's rmse: 6.2258
# fold 4
# Training until validation scores don't improve for 600 rounds.
# [100]	training's rmse: 6.30543	valid_1's rmse: 6.12005
# [200]	training's rmse: 6.11406	valid_1's rmse: 6.08451
# [300]	training's rmse: 5.97906	valid_1's rmse: 6.07549
# [400]	training's rmse: 5.87603	valid_1's rmse: 6.06965
# [500]	training's rmse: 5.79379	valid_1's rmse: 6.06422
# [600]	training's rmse: 5.72015	valid_1's rmse: 6.06348
# [700]	training's rmse: 5.6531	valid_1's rmse: 6.06093
# [800]	training's rmse: 5.58829	valid_1's rmse: 6.06147
# [900]	training's rmse: 5.52632	valid_1's rmse: 6.06243
# [1000]	training's rmse: 5.46923	valid_1's rmse: 6.06179
# [1100]	training's rmse: 5.41136	valid_1's rmse: 6.06096
# [1200]	training's rmse: 5.35555	valid_1's rmse: 6.06076
# [1300]	training's rmse: 5.30187	valid_1's rmse: 6.06093
# [1400]	training's rmse: 5.24769	valid_1's rmse: 6.06086
# [1500]	training's rmse: 5.19741	valid_1's rmse: 6.06193
# [1600]	training's rmse: 5.14732	valid_1's rmse: 6.06169
# [1700]	training's rmse: 5.09936	valid_1's rmse: 6.06224
# Early stopping, best iteration is:
# [1131]	training's rmse: 5.39375	valid_1's rmse: 6.06003
# fold 5
# Training until validation scores don't improve for 600 rounds.
# [100]	training's rmse: 6.24905	valid_1's rmse: 6.65337
# [200]	training's rmse: 6.05941	valid_1's rmse: 6.594
# [300]	training's rmse: 5.92716	valid_1's rmse: 6.57502
# [400]	training's rmse: 5.82276	valid_1's rmse: 6.5631
# [500]	training's rmse: 5.7399	valid_1's rmse: 6.55919
# [600]	training's rmse: 5.66356	valid_1's rmse: 6.55587
# [700]	training's rmse: 5.59538	valid_1's rmse: 6.55304
# [800]	training's rmse: 5.5307	valid_1's rmse: 6.54945
# [900]	training's rmse: 5.46895	valid_1's rmse: 6.54935
# [1000]	training's rmse: 5.41247	valid_1's rmse: 6.54888
# [1100]	training's rmse: 5.35598	valid_1's rmse: 6.54858
# [1200]	training's rmse: 5.30144	valid_1's rmse: 6.54917
# [1300]	training's rmse: 5.24732	valid_1's rmse: 6.54816
# [1400]	training's rmse: 5.19583	valid_1's rmse: 6.54745
# [1500]	training's rmse: 5.14623	valid_1's rmse: 6.54871
# [1600]	training's rmse: 5.09676	valid_1's rmse: 6.55017
# [1700]	training's rmse: 5.0492	valid_1's rmse: 6.55206
# [1800]	training's rmse: 5.00147	valid_1's rmse: 6.55238
# [1900]	training's rmse: 4.95431	valid_1's rmse: 6.55174
# Early stopping, best iteration is:
# [1332]	training's rmse: 5.23055	valid_1's rmse: 6.54693
# fold 6
# Training until validation scores don't improve for 600 rounds.
# [100]	training's rmse: 6.30838	valid_1's rmse: 6.08187
# [200]	training's rmse: 6.11314	valid_1's rmse: 6.05373
# [300]	training's rmse: 5.98057	valid_1's rmse: 6.04659
# [400]	training's rmse: 5.87546	valid_1's rmse: 6.043
# [500]	training's rmse: 5.78735	valid_1's rmse: 6.03953
# [600]	training's rmse: 5.71294	valid_1's rmse: 6.03596
# [700]	training's rmse: 5.64656	valid_1's rmse: 6.03536
# [800]	training's rmse: 5.58134	valid_1's rmse: 6.03484
# [900]	training's rmse: 5.52157	valid_1's rmse: 6.03437
# [1000]	training's rmse: 5.46308	valid_1's rmse: 6.03077
# [1100]	training's rmse: 5.40507	valid_1's rmse: 6.03086
# [1200]	training's rmse: 5.35046	valid_1's rmse: 6.03093
# [1300]	training's rmse: 5.2946	valid_1's rmse: 6.03233
# [1400]	training's rmse: 5.2399	valid_1's rmse: 6.03249
# [1500]	training's rmse: 5.18793	valid_1's rmse: 6.03438
# [1600]	training's rmse: 5.13977	valid_1's rmse: 6.03458
# Early stopping, best iteration is:
# [1040]	training's rmse: 5.43869	valid_1's rmse: 6.03005
# fold 7
# Training until validation scores don't improve for 600 rounds.
# [100]	training's rmse: 6.25328	valid_1's rmse: 6.62528
# [200]	training's rmse: 6.05964	valid_1's rmse: 6.58705
# [300]	training's rmse: 5.92925	valid_1's rmse: 6.57366
# [400]	training's rmse: 5.8251	valid_1's rmse: 6.5653
# [500]	training's rmse: 5.74225	valid_1's rmse: 6.55888
# [600]	training's rmse: 5.66877	valid_1's rmse: 6.55519
# [700]	training's rmse: 5.60445	valid_1's rmse: 6.55272
# [800]	training's rmse: 5.54128	valid_1's rmse: 6.55308
# [900]	training's rmse: 5.48169	valid_1's rmse: 6.55387
# [1000]	training's rmse: 5.4232	valid_1's rmse: 6.55213
# [1100]	training's rmse: 5.3669	valid_1's rmse: 6.55163
# [1200]	training's rmse: 5.31186	valid_1's rmse: 6.55047
# [1300]	training's rmse: 5.25806	valid_1's rmse: 6.54933
# [1400]	training's rmse: 5.20542	valid_1's rmse: 6.54754
# [1500]	training's rmse: 5.15351	valid_1's rmse: 6.54872
# [1600]	training's rmse: 5.10352	valid_1's rmse: 6.54779
# [1700]	training's rmse: 5.05371	valid_1's rmse: 6.54753
# [1800]	training's rmse: 5.00714	valid_1's rmse: 6.54844
# [1900]	training's rmse: 4.96197	valid_1's rmse: 6.54756
# [2000]	training's rmse: 4.91717	valid_1's rmse: 6.54765
# [2100]	training's rmse: 4.87243	valid_1's rmse: 6.54668
# [2200]	training's rmse: 4.83205	valid_1's rmse: 6.5462
# [2300]	training's rmse: 4.78918	valid_1's rmse: 6.54593
# [2400]	training's rmse: 4.74696	valid_1's rmse: 6.54683
# [2500]	training's rmse: 4.70699	valid_1's rmse: 6.54763
# [2600]	training's rmse: 4.66675	valid_1's rmse: 6.5492
# [2700]	training's rmse: 4.62764	valid_1's rmse: 6.54942
# [2800]	training's rmse: 4.58851	valid_1's rmse: 6.54868
# Early stopping, best iteration is:
# [2262]	training's rmse: 4.80539	valid_1's rmse: 6.54504
# fold 8
# Training until validation scores don't improve for 600 rounds.
# [100]	training's rmse: 6.24154	valid_1's rmse: 6.7117
# [200]	training's rmse: 6.05233	valid_1's rmse: 6.66061
# [300]	training's rmse: 5.92027	valid_1's rmse: 6.64546
# [400]	training's rmse: 5.82058	valid_1's rmse: 6.63409
# [500]	training's rmse: 5.73864	valid_1's rmse: 6.62785
# [600]	training's rmse: 5.66404	valid_1's rmse: 6.62659
# [700]	training's rmse: 5.59682	valid_1's rmse: 6.62404
# [800]	training's rmse: 5.53087	valid_1's rmse: 6.62396
# [900]	training's rmse: 5.46967	valid_1's rmse: 6.62284
# [1000]	training's rmse: 5.41185	valid_1's rmse: 6.62146
# [1100]	training's rmse: 5.3553	valid_1's rmse: 6.62169
# [1200]	training's rmse: 5.29931	valid_1's rmse: 6.62261
# [1300]	training's rmse: 5.24718	valid_1's rmse: 6.62465
# [1400]	training's rmse: 5.19315	valid_1's rmse: 6.62491
# [1500]	training's rmse: 5.14274	valid_1's rmse: 6.62609
# [1600]	training's rmse: 5.09143	valid_1's rmse: 6.62592
# Early stopping, best iteration is:
# [1055]	training's rmse: 5.38026	valid_1's rmse: 6.6206
# fold 9
# Training until validation scores don't improve for 600 rounds.
# [100]	training's rmse: 6.26007	valid_1's rmse: 6.57007
# [200]	training's rmse: 6.07155	valid_1's rmse: 6.49452
# [300]	training's rmse: 5.94217	valid_1's rmse: 6.46252
# [400]	training's rmse: 5.84186	valid_1's rmse: 6.4471
# [500]	training's rmse: 5.75981	valid_1's rmse: 6.43727
# [600]	training's rmse: 5.68694	valid_1's rmse: 6.43456
# [700]	training's rmse: 5.62004	valid_1's rmse: 6.4296
# [800]	training's rmse: 5.5556	valid_1's rmse: 6.42625
# [900]	training's rmse: 5.49321	valid_1's rmse: 6.42556
# [1000]	training's rmse: 5.43374	valid_1's rmse: 6.42646
# [1100]	training's rmse: 5.3753	valid_1's rmse: 6.42669
# [1200]	training's rmse: 5.31968	valid_1's rmse: 6.4277
# [1300]	training's rmse: 5.26728	valid_1's rmse: 6.42965
# [1400]	training's rmse: 5.21571	valid_1's rmse: 6.42936
# Early stopping, best iteration is:
# [876]	training's rmse: 5.50769	valid_1's rmse: 6.4249
# 6.346507552001286
# fold 0
# Training until validation scores don't improve for 600 rounds.
# [100]	training's rmse: 1.60584	valid_1's rmse: 1.60486
# [200]	training's rmse: 1.57404	valid_1's rmse: 1.57588
# [300]	training's rmse: 1.5589	valid_1's rmse: 1.56405
# [400]	training's rmse: 1.54876	valid_1's rmse: 1.55776
# [500]	training's rmse: 1.54082	valid_1's rmse: 1.55397
# [600]	training's rmse: 1.5341	valid_1's rmse: 1.5515
# [700]	training's rmse: 1.52818	valid_1's rmse: 1.54997
# [800]	training's rmse: 1.52291	valid_1's rmse: 1.54898
# [900]	training's rmse: 1.518	valid_1's rmse: 1.54838
# [1000]	training's rmse: 1.51343	valid_1's rmse: 1.5479
# [1100]	training's rmse: 1.5091	valid_1's rmse: 1.54755
# [1200]	training's rmse: 1.50484	valid_1's rmse: 1.5472
# [1300]	training's rmse: 1.50075	valid_1's rmse: 1.54686
# [1400]	training's rmse: 1.49681	valid_1's rmse: 1.54661
# [1500]	training's rmse: 1.49295	valid_1's rmse: 1.54649
# [1600]	training's rmse: 1.48923	valid_1's rmse: 1.54617
# [1700]	training's rmse: 1.48551	valid_1's rmse: 1.54605
# [1800]	training's rmse: 1.48183	valid_1's rmse: 1.54591
# [1900]	training's rmse: 1.4783	valid_1's rmse: 1.54571
# [2000]	training's rmse: 1.47478	valid_1's rmse: 1.54566
# [2100]	training's rmse: 1.4712	valid_1's rmse: 1.54554
# [2200]	training's rmse: 1.46767	valid_1's rmse: 1.54551
# [2300]	training's rmse: 1.46426	valid_1's rmse: 1.54551
# [2400]	training's rmse: 1.46092	valid_1's rmse: 1.54547
# [2500]	training's rmse: 1.45752	valid_1's rmse: 1.54543
# [2600]	training's rmse: 1.45413	valid_1's rmse: 1.54544
# [2700]	training's rmse: 1.4509	valid_1's rmse: 1.54551
# [2800]	training's rmse: 1.44755	valid_1's rmse: 1.54551
# [2900]	training's rmse: 1.44429	valid_1's rmse: 1.54553
# [3000]	training's rmse: 1.44101	valid_1's rmse: 1.54535
# [3100]	training's rmse: 1.43767	valid_1's rmse: 1.54535
# [3200]	training's rmse: 1.43444	valid_1's rmse: 1.5453
# [3300]	training's rmse: 1.43124	valid_1's rmse: 1.54521
# [3400]	training's rmse: 1.42805	valid_1's rmse: 1.54513
# [3500]	training's rmse: 1.4249	valid_1's rmse: 1.54512
# [3600]	training's rmse: 1.42176	valid_1's rmse: 1.54506
# [3700]	training's rmse: 1.41866	valid_1's rmse: 1.54515
# [3800]	training's rmse: 1.41558	valid_1's rmse: 1.54507
# [3900]	training's rmse: 1.41246	valid_1's rmse: 1.54517
# [4000]	training's rmse: 1.40941	valid_1's rmse: 1.54509
# [4100]	training's rmse: 1.40645	valid_1's rmse: 1.54514
# Early stopping, best iteration is:
# [3555]	training's rmse: 1.42316	valid_1's rmse: 1.54503
# fold 1
# Training until validation scores don't improve for 600 rounds.
# [100]	training's rmse: 1.60576	valid_1's rmse: 1.6034
# [200]	training's rmse: 1.57352	valid_1's rmse: 1.57736
# [300]	training's rmse: 1.55823	valid_1's rmse: 1.56718
# [400]	training's rmse: 1.54802	valid_1's rmse: 1.56195
# [500]	training's rmse: 1.54011	valid_1's rmse: 1.55899
# [600]	training's rmse: 1.53332	valid_1's rmse: 1.55687
# [700]	training's rmse: 1.52728	valid_1's rmse: 1.55568
# [800]	training's rmse: 1.52189	valid_1's rmse: 1.55478
# [900]	training's rmse: 1.51703	valid_1's rmse: 1.55425
# [1000]	training's rmse: 1.51244	valid_1's rmse: 1.55379
# [1100]	training's rmse: 1.50811	valid_1's rmse: 1.55345
# [1200]	training's rmse: 1.5039	valid_1's rmse: 1.55337
# [1300]	training's rmse: 1.49996	valid_1's rmse: 1.55311
# [1400]	training's rmse: 1.49595	valid_1's rmse: 1.55291
# [1500]	training's rmse: 1.49214	valid_1's rmse: 1.55281
# [1600]	training's rmse: 1.4884	valid_1's rmse: 1.55258
# [1700]	training's rmse: 1.48484	valid_1's rmse: 1.55243
# [1800]	training's rmse: 1.48121	valid_1's rmse: 1.55239
# [1900]	training's rmse: 1.47763	valid_1's rmse: 1.55226
# [2000]	training's rmse: 1.47417	valid_1's rmse: 1.55212
# [2100]	training's rmse: 1.47077	valid_1's rmse: 1.55207
# [2200]	training's rmse: 1.46731	valid_1's rmse: 1.552
# [2300]	training's rmse: 1.46395	valid_1's rmse: 1.55194
# [2400]	training's rmse: 1.46054	valid_1's rmse: 1.55197
# [2500]	training's rmse: 1.45725	valid_1's rmse: 1.5519
# [2600]	training's rmse: 1.45391	valid_1's rmse: 1.55187
# [2700]	training's rmse: 1.45065	valid_1's rmse: 1.5519
# [2800]	training's rmse: 1.44753	valid_1's rmse: 1.55193
# [2900]	training's rmse: 1.4442	valid_1's rmse: 1.55208
# [3000]	training's rmse: 1.44102	valid_1's rmse: 1.55192
# [3100]	training's rmse: 1.4378	valid_1's rmse: 1.55189
# [3200]	training's rmse: 1.43463	valid_1's rmse: 1.55188
# [3300]	training's rmse: 1.43148	valid_1's rmse: 1.5518
# [3400]	training's rmse: 1.42846	valid_1's rmse: 1.55185
# [3500]	training's rmse: 1.42524	valid_1's rmse: 1.55186
# [3600]	training's rmse: 1.42213	valid_1's rmse: 1.55192
# [3700]	training's rmse: 1.41906	valid_1's rmse: 1.55185
# [3800]	training's rmse: 1.41599	valid_1's rmse: 1.55188
# Early stopping, best iteration is:
# [3287]	training's rmse: 1.4319	valid_1's rmse: 1.55176
# fold 2
# Training until validation scores don't improve for 600 rounds.
# [100]	training's rmse: 1.60403	valid_1's rmse: 1.61951
# [200]	training's rmse: 1.57169	valid_1's rmse: 1.59329
# [300]	training's rmse: 1.55632	valid_1's rmse: 1.58347
# [400]	training's rmse: 1.54593	valid_1's rmse: 1.57849
# [500]	training's rmse: 1.53794	valid_1's rmse: 1.57563
# [600]	training's rmse: 1.53118	valid_1's rmse: 1.57401
# [700]	training's rmse: 1.52534	valid_1's rmse: 1.57262
# [800]	training's rmse: 1.52007	valid_1's rmse: 1.57185
# [900]	training's rmse: 1.51522	valid_1's rmse: 1.57134
# [1000]	training's rmse: 1.51065	valid_1's rmse: 1.57096
# [1100]	training's rmse: 1.50629	valid_1's rmse: 1.57073
# [1200]	training's rmse: 1.50221	valid_1's rmse: 1.57068
# [1300]	training's rmse: 1.49812	valid_1's rmse: 1.57039
# [1400]	training's rmse: 1.49422	valid_1's rmse: 1.57033
# [1500]	training's rmse: 1.49036	valid_1's rmse: 1.57033
# [1600]	training's rmse: 1.48664	valid_1's rmse: 1.5702
# [1700]	training's rmse: 1.48296	valid_1's rmse: 1.57007
# [1800]	training's rmse: 1.47934	valid_1's rmse: 1.57
# [1900]	training's rmse: 1.47578	valid_1's rmse: 1.56987
# [2000]	training's rmse: 1.47218	valid_1's rmse: 1.56988
# [2100]	training's rmse: 1.46859	valid_1's rmse: 1.5699
# [2200]	training's rmse: 1.46515	valid_1's rmse: 1.56991
# [2300]	training's rmse: 1.46174	valid_1's rmse: 1.56985
# [2400]	training's rmse: 1.45838	valid_1's rmse: 1.56989
# [2500]	training's rmse: 1.45503	valid_1's rmse: 1.57002
# Early stopping, best iteration is:
# [1971]	training's rmse: 1.47322	valid_1's rmse: 1.56983
# fold 3
# Training until validation scores don't improve for 600 rounds.
# [100]	training's rmse: 1.60628	valid_1's rmse: 1.59849
# [200]	training's rmse: 1.57433	valid_1's rmse: 1.57112
# [300]	training's rmse: 1.55916	valid_1's rmse: 1.56041
# [400]	training's rmse: 1.54896	valid_1's rmse: 1.55481
# [500]	training's rmse: 1.54106	valid_1's rmse: 1.55135
# [600]	training's rmse: 1.53431	valid_1's rmse: 1.54901
# [700]	training's rmse: 1.52835	valid_1's rmse: 1.5476
# [800]	training's rmse: 1.52305	valid_1's rmse: 1.54669
# [900]	training's rmse: 1.51824	valid_1's rmse: 1.54593
# [1000]	training's rmse: 1.51371	valid_1's rmse: 1.54547
# [1100]	training's rmse: 1.50932	valid_1's rmse: 1.54503
# [1200]	training's rmse: 1.50521	valid_1's rmse: 1.54475
# [1300]	training's rmse: 1.50117	valid_1's rmse: 1.54456
# [1400]	training's rmse: 1.4972	valid_1's rmse: 1.54435
# [1500]	training's rmse: 1.4933	valid_1's rmse: 1.54408
# [1600]	training's rmse: 1.48943	valid_1's rmse: 1.54403
# [1700]	training's rmse: 1.48568	valid_1's rmse: 1.54401
# [1800]	training's rmse: 1.48212	valid_1's rmse: 1.5439
# [1900]	training's rmse: 1.47858	valid_1's rmse: 1.54379
# [2000]	training's rmse: 1.47499	valid_1's rmse: 1.54381
# [2100]	training's rmse: 1.4714	valid_1's rmse: 1.54367
# [2200]	training's rmse: 1.46793	valid_1's rmse: 1.54356
# [2300]	training's rmse: 1.46449	valid_1's rmse: 1.54343
# [2400]	training's rmse: 1.46115	valid_1's rmse: 1.54341
# [2500]	training's rmse: 1.45776	valid_1's rmse: 1.54331
# [2600]	training's rmse: 1.45434	valid_1's rmse: 1.54332
# [2700]	training's rmse: 1.45108	valid_1's rmse: 1.54335
# [2800]	training's rmse: 1.44779	valid_1's rmse: 1.54328
# [2900]	training's rmse: 1.44444	valid_1's rmse: 1.54327
# [3000]	training's rmse: 1.44113	valid_1's rmse: 1.54316
# [3100]	training's rmse: 1.43788	valid_1's rmse: 1.54316
# [3200]	training's rmse: 1.4346	valid_1's rmse: 1.54319
# [3300]	training's rmse: 1.43134	valid_1's rmse: 1.54323
# [3400]	training's rmse: 1.42815	valid_1's rmse: 1.54321
# [3500]	training's rmse: 1.42501	valid_1's rmse: 1.54329
# [3600]	training's rmse: 1.42186	valid_1's rmse: 1.54336
# Early stopping, best iteration is:
# [3021]	training's rmse: 1.44044	valid_1's rmse: 1.54311
# fold 4
# Training until validation scores don't improve for 600 rounds.
# [100]	training's rmse: 1.60693	valid_1's rmse: 1.59463
# [200]	training's rmse: 1.57489	valid_1's rmse: 1.5671
# [300]	training's rmse: 1.55967	valid_1's rmse: 1.55656
# [400]	training's rmse: 1.54941	valid_1's rmse: 1.55061
# [500]	training's rmse: 1.54131	valid_1's rmse: 1.54693
# [600]	training's rmse: 1.53446	valid_1's rmse: 1.54436
# [700]	training's rmse: 1.52856	valid_1's rmse: 1.54284
# [800]	training's rmse: 1.52322	valid_1's rmse: 1.54179
# [900]	training's rmse: 1.51832	valid_1's rmse: 1.54113
# [1000]	training's rmse: 1.5137	valid_1's rmse: 1.54059
# [1100]	training's rmse: 1.50932	valid_1's rmse: 1.54033
# [1200]	training's rmse: 1.50511	valid_1's rmse: 1.53999
# [1300]	training's rmse: 1.50109	valid_1's rmse: 1.5398
# [1400]	training's rmse: 1.49702	valid_1's rmse: 1.53963
# [1500]	training's rmse: 1.49314	valid_1's rmse: 1.53956
# [1600]	training's rmse: 1.48931	valid_1's rmse: 1.53944
# [1700]	training's rmse: 1.48548	valid_1's rmse: 1.53926
# [1800]	training's rmse: 1.48182	valid_1's rmse: 1.53916
# [1900]	training's rmse: 1.47817	valid_1's rmse: 1.53906
# [2000]	training's rmse: 1.47456	valid_1's rmse: 1.53907
# [2100]	training's rmse: 1.47099	valid_1's rmse: 1.53897
# [2200]	training's rmse: 1.46751	valid_1's rmse: 1.53882
# [2300]	training's rmse: 1.46407	valid_1's rmse: 1.53879
# [2400]	training's rmse: 1.46063	valid_1's rmse: 1.53869
# [2500]	training's rmse: 1.45725	valid_1's rmse: 1.53866
# [2600]	training's rmse: 1.45386	valid_1's rmse: 1.53878
# [2700]	training's rmse: 1.45058	valid_1's rmse: 1.53876
# [2800]	training's rmse: 1.4473	valid_1's rmse: 1.53872
# [2900]	training's rmse: 1.44415	valid_1's rmse: 1.53863
# [3000]	training's rmse: 1.44086	valid_1's rmse: 1.53865
# [3100]	training's rmse: 1.43761	valid_1's rmse: 1.5387
# [3200]	training's rmse: 1.43438	valid_1's rmse: 1.5386
# [3300]	training's rmse: 1.43131	valid_1's rmse: 1.53864
# [3400]	training's rmse: 1.42819	valid_1's rmse: 1.5387
# [3500]	training's rmse: 1.42511	valid_1's rmse: 1.53869
# [3600]	training's rmse: 1.42211	valid_1's rmse: 1.53874
# [3700]	training's rmse: 1.4189	valid_1's rmse: 1.53882
# [3800]	training's rmse: 1.41592	valid_1's rmse: 1.53883
# Early stopping, best iteration is:
# [3202]	training's rmse: 1.43433	valid_1's rmse: 1.53859
# fold 5
# Training until validation scores don't improve for 600 rounds.
# [100]	training's rmse: 1.60366	valid_1's rmse: 1.62367
# [200]	training's rmse: 1.5716	valid_1's rmse: 1.5962
# [300]	training's rmse: 1.55619	valid_1's rmse: 1.58528
# [400]	training's rmse: 1.54587	valid_1's rmse: 1.58007
# [500]	training's rmse: 1.53797	valid_1's rmse: 1.57684
# [600]	training's rmse: 1.53117	valid_1's rmse: 1.57466
# [700]	training's rmse: 1.52532	valid_1's rmse: 1.57335
# [800]	training's rmse: 1.51998	valid_1's rmse: 1.57249
# [900]	training's rmse: 1.51515	valid_1's rmse: 1.57205
# [1000]	training's rmse: 1.51064	valid_1's rmse: 1.57178
# [1100]	training's rmse: 1.50624	valid_1's rmse: 1.57142
# [1200]	training's rmse: 1.50207	valid_1's rmse: 1.57122
# [1300]	training's rmse: 1.49805	valid_1's rmse: 1.57114
# [1400]	training's rmse: 1.49412	valid_1's rmse: 1.57095
# [1500]	training's rmse: 1.49019	valid_1's rmse: 1.57081
# [1600]	training's rmse: 1.48635	valid_1's rmse: 1.57067
# [1700]	training's rmse: 1.48267	valid_1's rmse: 1.57056
# [1800]	training's rmse: 1.47898	valid_1's rmse: 1.57061
# [1900]	training's rmse: 1.47532	valid_1's rmse: 1.57045
# [2000]	training's rmse: 1.47165	valid_1's rmse: 1.57031
# [2100]	training's rmse: 1.46817	valid_1's rmse: 1.57035
# [2200]	training's rmse: 1.46467	valid_1's rmse: 1.57036
# [2300]	training's rmse: 1.46119	valid_1's rmse: 1.57041
# [2400]	training's rmse: 1.45765	valid_1's rmse: 1.57043
# [2500]	training's rmse: 1.45424	valid_1's rmse: 1.57041
# Early stopping, best iteration is:
# [1993]	training's rmse: 1.4719	valid_1's rmse: 1.57028
# fold 6
# Training until validation scores don't improve for 600 rounds.
# [100]	training's rmse: 1.60397	valid_1's rmse: 1.62094
# [200]	training's rmse: 1.57209	valid_1's rmse: 1.59219
# [300]	training's rmse: 1.55684	valid_1's rmse: 1.58071
# [400]	training's rmse: 1.5467	valid_1's rmse: 1.57444
# [500]	training's rmse: 1.53872	valid_1's rmse: 1.57072
# [600]	training's rmse: 1.5319	valid_1's rmse: 1.56831
# [700]	training's rmse: 1.52594	valid_1's rmse: 1.5667
# [800]	training's rmse: 1.52064	valid_1's rmse: 1.56573
# [900]	training's rmse: 1.51569	valid_1's rmse: 1.5651
# [1000]	training's rmse: 1.51102	valid_1's rmse: 1.56461
# [1100]	training's rmse: 1.5066	valid_1's rmse: 1.56433
# [1200]	training's rmse: 1.50252	valid_1's rmse: 1.56405
# [1300]	training's rmse: 1.49855	valid_1's rmse: 1.56384
# [1400]	training's rmse: 1.49454	valid_1's rmse: 1.56358
# [1500]	training's rmse: 1.49075	valid_1's rmse: 1.56345
# [1600]	training's rmse: 1.487	valid_1's rmse: 1.5634
# [1700]	training's rmse: 1.48325	valid_1's rmse: 1.56321
# [1800]	training's rmse: 1.47966	valid_1's rmse: 1.56317
# [1900]	training's rmse: 1.47611	valid_1's rmse: 1.56314
# [2000]	training's rmse: 1.47261	valid_1's rmse: 1.56305
# [2100]	training's rmse: 1.46904	valid_1's rmse: 1.56298
# [2200]	training's rmse: 1.46563	valid_1's rmse: 1.56274
# [2300]	training's rmse: 1.46217	valid_1's rmse: 1.56285
# [2400]	training's rmse: 1.45876	valid_1's rmse: 1.56286
# [2500]	training's rmse: 1.45538	valid_1's rmse: 1.56276
# [2600]	training's rmse: 1.45204	valid_1's rmse: 1.56269
# [2700]	training's rmse: 1.44876	valid_1's rmse: 1.56269
# [2800]	training's rmse: 1.44547	valid_1's rmse: 1.5626
# [2900]	training's rmse: 1.44219	valid_1's rmse: 1.5627
# [3000]	training's rmse: 1.43896	valid_1's rmse: 1.56273
# [3100]	training's rmse: 1.43581	valid_1's rmse: 1.56268
# [3200]	training's rmse: 1.43261	valid_1's rmse: 1.56271
# [3300]	training's rmse: 1.42943	valid_1's rmse: 1.56269
# Early stopping, best iteration is:
# [2799]	training's rmse: 1.44551	valid_1's rmse: 1.5626
# fold 7
# Training until validation scores don't improve for 600 rounds.
# [100]	training's rmse: 1.60641	valid_1's rmse: 1.59966
# [200]	training's rmse: 1.57445	valid_1's rmse: 1.5705
# [300]	training's rmse: 1.55925	valid_1's rmse: 1.55932
# [400]	training's rmse: 1.54898	valid_1's rmse: 1.55301
# [500]	training's rmse: 1.54097	valid_1's rmse: 1.54943
# [600]	training's rmse: 1.53425	valid_1's rmse: 1.54735
# [700]	training's rmse: 1.52831	valid_1's rmse: 1.54559
# [800]	training's rmse: 1.523	valid_1's rmse: 1.54458
# [900]	training's rmse: 1.51816	valid_1's rmse: 1.54394
# [1000]	training's rmse: 1.51361	valid_1's rmse: 1.54346
# [1100]	training's rmse: 1.50921	valid_1's rmse: 1.54326
# [1200]	training's rmse: 1.505	valid_1's rmse: 1.54296
# [1300]	training's rmse: 1.50092	valid_1's rmse: 1.54284
# [1400]	training's rmse: 1.49689	valid_1's rmse: 1.54275
# [1500]	training's rmse: 1.49288	valid_1's rmse: 1.54258
# [1600]	training's rmse: 1.48907	valid_1's rmse: 1.54239
# [1700]	training's rmse: 1.48531	valid_1's rmse: 1.5423
# [1800]	training's rmse: 1.48164	valid_1's rmse: 1.54225
# [1900]	training's rmse: 1.4781	valid_1's rmse: 1.5422
# [2000]	training's rmse: 1.4745	valid_1's rmse: 1.54207
# [2100]	training's rmse: 1.47089	valid_1's rmse: 1.54202
# [2200]	training's rmse: 1.46751	valid_1's rmse: 1.54193
# [2300]	training's rmse: 1.46404	valid_1's rmse: 1.54179
# [2400]	training's rmse: 1.46051	valid_1's rmse: 1.54172
# [2500]	training's rmse: 1.45703	valid_1's rmse: 1.54169
# [2600]	training's rmse: 1.45368	valid_1's rmse: 1.54175
# [2700]	training's rmse: 1.45036	valid_1's rmse: 1.54166
# [2800]	training's rmse: 1.44694	valid_1's rmse: 1.54169
# [2900]	training's rmse: 1.44374	valid_1's rmse: 1.5417
# [3000]	training's rmse: 1.44044	valid_1's rmse: 1.54169
# [3100]	training's rmse: 1.43716	valid_1's rmse: 1.54166
# [3200]	training's rmse: 1.43391	valid_1's rmse: 1.54167
# [3300]	training's rmse: 1.43081	valid_1's rmse: 1.54178
# [3400]	training's rmse: 1.42769	valid_1's rmse: 1.54183
# [3500]	training's rmse: 1.42462	valid_1's rmse: 1.54179
# [3600]	training's rmse: 1.42141	valid_1's rmse: 1.54173
# [3700]	training's rmse: 1.41828	valid_1's rmse: 1.54168
# Early stopping, best iteration is:
# [3155]	training's rmse: 1.43535	valid_1's rmse: 1.54162
# fold 8
# Training until validation scores don't improve for 600 rounds.
# [100]	training's rmse: 1.60472	valid_1's rmse: 1.61459
# [200]	training's rmse: 1.57296	valid_1's rmse: 1.58519
# [300]	training's rmse: 1.55775	valid_1's rmse: 1.57282
# [400]	training's rmse: 1.54755	valid_1's rmse: 1.56629
# [500]	training's rmse: 1.53953	valid_1's rmse: 1.5622
# [600]	training's rmse: 1.53277	valid_1's rmse: 1.5595
# [700]	training's rmse: 1.52691	valid_1's rmse: 1.55797
# [800]	training's rmse: 1.52162	valid_1's rmse: 1.55676
# [900]	training's rmse: 1.51669	valid_1's rmse: 1.55589
# [1000]	training's rmse: 1.5122	valid_1's rmse: 1.55518
# [1100]	training's rmse: 1.50792	valid_1's rmse: 1.55467
# [1200]	training's rmse: 1.50381	valid_1's rmse: 1.55438
# [1300]	training's rmse: 1.49971	valid_1's rmse: 1.55409
# [1400]	training's rmse: 1.49579	valid_1's rmse: 1.55373
# [1500]	training's rmse: 1.49189	valid_1's rmse: 1.55359
# [1600]	training's rmse: 1.48819	valid_1's rmse: 1.55338
# [1700]	training's rmse: 1.48455	valid_1's rmse: 1.55331
# [1800]	training's rmse: 1.48092	valid_1's rmse: 1.55324
# [1900]	training's rmse: 1.47733	valid_1's rmse: 1.55315
# [2000]	training's rmse: 1.47371	valid_1's rmse: 1.55306
# [2100]	training's rmse: 1.47023	valid_1's rmse: 1.55309
# [2200]	training's rmse: 1.46665	valid_1's rmse: 1.55294
# [2300]	training's rmse: 1.46319	valid_1's rmse: 1.55299
# [2400]	training's rmse: 1.45979	valid_1's rmse: 1.55273
# [2500]	training's rmse: 1.45641	valid_1's rmse: 1.55263
# [2600]	training's rmse: 1.45315	valid_1's rmse: 1.55248
# [2700]	training's rmse: 1.44981	valid_1's rmse: 1.55243
# [2800]	training's rmse: 1.44662	valid_1's rmse: 1.55237
# [2900]	training's rmse: 1.44341	valid_1's rmse: 1.55234
# [3000]	training's rmse: 1.44026	valid_1's rmse: 1.55232
# [3100]	training's rmse: 1.43708	valid_1's rmse: 1.55234
# [3200]	training's rmse: 1.43386	valid_1's rmse: 1.55231
# [3300]	training's rmse: 1.43061	valid_1's rmse: 1.55243
# [3400]	training's rmse: 1.4275	valid_1's rmse: 1.55236
# [3500]	training's rmse: 1.42441	valid_1's rmse: 1.55231
# [3600]	training's rmse: 1.42129	valid_1's rmse: 1.55235
# [3700]	training's rmse: 1.41822	valid_1's rmse: 1.55242
# [3800]	training's rmse: 1.41516	valid_1's rmse: 1.55239
# [3900]	training's rmse: 1.41211	valid_1's rmse: 1.55238
# [4000]	training's rmse: 1.40894	valid_1's rmse: 1.55248
# Early stopping, best iteration is:
# [3481]	training's rmse: 1.42503	valid_1's rmse: 1.55226
# fold 9
# Training until validation scores don't improve for 600 rounds.
# [100]	training's rmse: 1.60457	valid_1's rmse: 1.61428
# [200]	training's rmse: 1.57247	valid_1's rmse: 1.58749
# [300]	training's rmse: 1.55705	valid_1's rmse: 1.57698
# [400]	training's rmse: 1.54684	valid_1's rmse: 1.5717
# [500]	training's rmse: 1.53883	valid_1's rmse: 1.56828
# [600]	training's rmse: 1.53215	valid_1's rmse: 1.5662
# [700]	training's rmse: 1.52621	valid_1's rmse: 1.56463
# [800]	training's rmse: 1.52086	valid_1's rmse: 1.56364
# [900]	training's rmse: 1.51599	valid_1's rmse: 1.56307
# [1000]	training's rmse: 1.51146	valid_1's rmse: 1.56244
# [1100]	training's rmse: 1.50714	valid_1's rmse: 1.56199
# [1200]	training's rmse: 1.50294	valid_1's rmse: 1.56173
# [1300]	training's rmse: 1.49885	valid_1's rmse: 1.56121
# [1400]	training's rmse: 1.49486	valid_1's rmse: 1.56105
# [1500]	training's rmse: 1.49096	valid_1's rmse: 1.56082
# [1600]	training's rmse: 1.48715	valid_1's rmse: 1.56062
# [1700]	training's rmse: 1.48345	valid_1's rmse: 1.56042
# [1800]	training's rmse: 1.47983	valid_1's rmse: 1.56021
# [1900]	training's rmse: 1.47633	valid_1's rmse: 1.56009
# [2000]	training's rmse: 1.47277	valid_1's rmse: 1.55994
# [2100]	training's rmse: 1.46931	valid_1's rmse: 1.55977
# [2200]	training's rmse: 1.46591	valid_1's rmse: 1.55964
# [2300]	training's rmse: 1.4625	valid_1's rmse: 1.5595
# [2400]	training's rmse: 1.45906	valid_1's rmse: 1.55943
# [2500]	training's rmse: 1.45556	valid_1's rmse: 1.5594
# [2600]	training's rmse: 1.45228	valid_1's rmse: 1.55936
# [2700]	training's rmse: 1.44895	valid_1's rmse: 1.55932
# [2800]	training's rmse: 1.44569	valid_1's rmse: 1.5594
# [2900]	training's rmse: 1.44244	valid_1's rmse: 1.55935
# [3000]	training's rmse: 1.43921	valid_1's rmse: 1.55944
# [3100]	training's rmse: 1.43598	valid_1's rmse: 1.55937
# [3200]	training's rmse: 1.43273	valid_1's rmse: 1.55938
# [3300]	training's rmse: 1.42951	valid_1's rmse: 1.55943
# Early stopping, best iteration is:
# [2746]	training's rmse: 1.44741	valid_1's rmse: 1.55925
# 1.5534720439034135

# %%
multi_model = pd.DataFrame({"card_id":df_test["card_id"].values})
multi_model["target"] = all_test

# %%
multi_model[80000:80003]
# Out:
#                card_id    target
# 80000  C_ID_b4970c54ac -0.033300
# 80001  C_ID_bbd48580c0 -1.144877
# 80002  C_ID_77fde100b6 -3.249598

# %%
multi_model.to_csv('wang_lgb_cv_with_multi_model.csv', index=False)

# %%
best_submission = pd.read_csv('../input/elosinglemodel0105/submission.csv')
best_submission[80000:80003]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-42-69b7b82cc742> in <module>()
# ----> 1 best_submission = pd.read_csv('../input/elosinglemodel0105/submission.csv')
#       2 best_submission[80000:80003]
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     707                     skip_blank_lines=skip_blank_lines)
#     708
# --> 709         return _read(filepath_or_buffer, kwds)
#     710
#     711     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     447
#     448     # Create the parser.
# --> 449     parser = TextFileReader(filepath_or_buffer, **kwds)
#     450
#     451     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     816             self.options['has_index_names'] = kwds['has_index_names']
#     817
# --> 818         self._make_engine(self.engine)
#     819
#     820     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1047     def _make_engine(self, engine='c'):
#    1048         if engine == 'c':
# -> 1049             self._engine = CParserWrapper(self.f, **self.options)
#    1050         else:
#    1051             if engine == 'python':
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1693         kwds['allow_leading_cols'] = self.index_col is not False
#    1694
# -> 1695         self._reader = parsers.TextReader(src, **kwds)
#    1696
#    1697         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'../input/elosinglemodel0105/submission.csv' does not exist
