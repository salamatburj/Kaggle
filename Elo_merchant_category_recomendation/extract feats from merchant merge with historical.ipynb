# %%
import numpy as np
import pandas as pd
import datetime
import gc
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_squared_error
import warnings
import time
warnings.filterwarnings('ignore')
np.random.seed(4950)

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %%
df_merchant = pd.read_csv('../../ELO/merchants.csv')
df_hist_trans = pd.read_csv('../../ELO/historical_transactions.csv',usecols = ['card_id','merchant_id'])
# df_new_merchant_trans = pd.read_csv('../input/elo-merchant-category-recommendation/new_merchant_transactions.csv')

# %%
df_hist_trans = reduce_mem_usage(df_hist_trans)
df_merchant = reduce_mem_usage(df_merchant)
# Out:
# Mem. usage decreased to 444.22 Mb (0.0% reduction)
# Mem. usage decreased to 30.32 Mb (46.0% reduction)

# %%
df_new_merchant_trans = pd.read_csv('../../ELO/new_merchant_transactions.csv')
df_new_merchant_trans = reduce_mem_usage(df_new_merchant_trans)
# Out:
# Mem. usage decreased to 114.20 Mb (45.5% reduction)

# %%
df_train=pd.read_csv('train.csv',parse_dates=['first_active_month'])
df_test=pd.read_csv('test.csv',parse_dates=['first_active_month'])

# %%
df_merchant.head()
# Out:
#        merchant_id  merchant_group_id  merchant_category_id  subsector_id  \
# 0  M_ID_838061e48c               8353                   792             9
# 1  M_ID_9339d880ad               3184                   840            20
# 2  M_ID_e726bbae1e                447                   690             1
# 3  M_ID_a70e9c5f81               5026                   792             9
# 4  M_ID_64456c37ce               2228                   222            21
#
#    numerical_1  numerical_2 category_1 most_recent_sales_range  \
# 0    -0.057465    -0.057465          N                       E
# 1    -0.057465    -0.057465          N                       E
# 2    -0.057465    -0.057465          N                       E
# 3    -0.057465    -0.057465          Y                       E
# 4    -0.057465    -0.057465          Y                       E
#
#   most_recent_purchases_range  avg_sales_lag3     ...      avg_sales_lag6  \
# 0                           E       -0.400000     ...           -2.250000
# 1                           E       -0.720000     ...           -0.740000
# 2                           E      -82.129997     ...          -82.129997
# 3                           E             NaN     ...                 NaN
# 4                           E             NaN     ...                 NaN
#
#    avg_purchases_lag6  active_months_lag6  avg_sales_lag12  \
# 0           18.666667                   6        -2.320000
# 1            1.291667                   6        -0.570000
# 2          260.000000                   2       -82.129997
# 3            4.666667                   6              NaN
# 4            0.361111                   6              NaN
#
#    avg_purchases_lag12  active_months_lag12  category_4  city_id state_id  \
# 0            13.916667                   12           N      242        9
# 1             1.687500                   12           N       22       16
# 2           260.000000                    2           N       -1        5
# 3             3.833333                   12           Y       -1       -1
# 4             0.347222                   12           Y       -1       -1
#
#    category_2
# 0         1.0
# 1         1.0
# 2         5.0
# 3         NaN
# 4         NaN
#
# [5 rows x 22 columns]

# %%
df_hist_trans = df_hist_trans.merge(df_merchant, on = 'merchant_id', how = 'left')

# %%
df_hist_trans.head()
# Out:
#            card_id      merchant_id  merchant_group_id  merchant_category_id  \
# 0  C_ID_4e6213e9bc  M_ID_e020e9b302               35.0                  80.0
# 1  C_ID_4e6213e9bc  M_ID_86ec983688             2084.0                 367.0
# 2  C_ID_4e6213e9bc  M_ID_979ed661fc            27369.0                  80.0
# 3  C_ID_4e6213e9bc  M_ID_e6d5ae8ea6            24104.0                 560.0
# 4  C_ID_4e6213e9bc  M_ID_e020e9b302               35.0                  80.0
#
#    subsector_id  numerical_1  numerical_2 category_1 most_recent_sales_range  \
# 0          37.0    23.468750    23.015625          N                       A
# 1          16.0     1.092773    -0.057465          N                       A
# 2          37.0     0.021851     0.021851          N                       C
# 3          34.0    -0.057465    -0.057465          N                       D
# 4          37.0    23.468750    23.015625          N                       A
#
#   most_recent_purchases_range    ...      avg_sales_lag6  avg_purchases_lag6  \
# 0                           A    ...                1.14            1.114135
# 1                           A    ...                1.06            1.058605
# 2                           C    ...                0.98            0.967058
# 3                           C    ...                0.88            0.897406
# 4                           A    ...                1.14            1.114135
#
#    active_months_lag6  avg_sales_lag12  avg_purchases_lag12  \
# 0                 6.0             1.19             1.156844
# 1                 6.0             1.05             1.062087
# 2                 6.0             0.97             0.956668
# 3                 6.0             0.86             0.864394
# 4                 6.0             1.19             1.156844
#
#    active_months_lag12  category_4  city_id  state_id category_2
# 0                 12.0           Y     88.0      16.0        1.0
# 1                 12.0           Y     88.0      16.0        1.0
# 2                 12.0           Y     88.0      16.0        1.0
# 3                 12.0           Y     88.0      16.0        1.0
# 4                 12.0           Y     88.0      16.0        1.0
#
# [5 rows x 23 columns]

# %%
def get_new_columns(name,aggs):
    #for for 写法 nice
    return [name + '_' + k + '_' + agg for k in aggs.keys() for agg in aggs[k]]

# %%
del df_hist_trans['merchant_id']

# %%
for df in [df_hist_trans]:
    aggs = {}
    for col in ['most_recent_sales_range','most_recent_purchases_range','category_1','category_2','category_4',
                'subsector_id','merchant_category_id', 'state_id','city_id','merchant_group_id']:
        aggs[col] = ['nunique']
    for col in ['numerical_1','numerical_2']:
        aggs[col] =  ['sum','max','min','mean','var','median']
    for col in ['avg_sales_lag3','avg_purchases_lag3','active_months_lag3','avg_sales_lag6','avg_purchases_lag6',
               'active_months_lag6','avg_sales_lag12','avg_purchases_lag12','active_months_lag12']:
        aggs[col] = ['sum', 'mean']
#     features = ['category_2','category_3','state_id','subsector_id','merchant_category_id','city_id'
#                ,'merchant_id']
#     for col in features:
#         df[col+'_mean'] = df.groupby([col])['purchase_amount'].transform('mean')
#         df[col+'_sum'] = df.groupby([col])['purchase_amount'].transform('sum') 
#         aggs[col+'_mean'] = ['mean']
#         aggs[col+'_sum'] = ['sum'] 
    prefix = 'merchant_merge_hist'
    new_columns = get_new_columns(prefix,aggs)
    df_hist_trans_group = df.groupby('card_id').agg(aggs)
    df_hist_trans_group.columns = new_columns
    df_hist_trans_group.reset_index(drop=False,inplace=True)
    del df
    gc.collect()
    time.sleep(5)

# %%
df_hist_trans_group.head()
# Out:
#            card_id  merchant_merge_hist_most_recent_sales_range_nunique  \
# 0  C_ID_00007093c1                                                  5
# 1  C_ID_0001238066                                                  5
# 2  C_ID_0001506ef0                                                  5
# 3  C_ID_0001793786                                                  5
# 4  C_ID_000183fdda                                                  5
#
#    merchant_merge_hist_most_recent_purchases_range_nunique  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    merchant_merge_hist_category_1_nunique  \
# 0                                       2
# 1                                       2
# 2                                       2
# 3                                       2
# 4                                       2
#
#    merchant_merge_hist_category_2_nunique  \
# 0                                       1
# 1                                       2
# 2                                       1
# 3                                       3
# 4                                       1
#
#    merchant_merge_hist_category_4_nunique  \
# 0                                       2
# 1                                       2
# 2                                       2
# 3                                       2
# 4                                       2
#
#    merchant_merge_hist_subsector_id_nunique  \
# 0                                        12
# 1                                        17
# 2                                        12
# 3                                        23
# 4                                        20
#
#    merchant_merge_hist_merchant_category_id_nunique  \
# 0                                                18
# 1                                                27
# 2                                                17
# 3                                                46
# 4                                                35
#
#    merchant_merge_hist_state_id_nunique  merchant_merge_hist_city_id_nunique  \
# 0                                     2                                    2
# 1                                     5                                   16
# 2                                     2                                    3
# 3                                     4                                    7
# 4                                     4                                    3
#
#                        ...                       \
# 0                      ...
# 1                      ...
# 2                      ...
# 3                      ...
# 4                      ...
#
#    merchant_merge_hist_avg_purchases_lag6_sum  \
# 0                                  156.494324
# 1                                  655.069438
# 2                                  103.265523
# 3                                  607.345252
# 4                                 1250.224477
#
#    merchant_merge_hist_avg_purchases_lag6_mean  \
# 0                                     1.050297
# 1                                     5.325768
# 2                                     1.518611
# 3                                     2.735789
# 4                                     8.390768
#
#    merchant_merge_hist_active_months_lag6_sum  \
# 0                                       894.0
# 1                                       738.0
# 2                                       408.0
# 3                                      1332.0
# 4                                       894.0
#
#    merchant_merge_hist_active_months_lag6_mean  \
# 0                                          6.0
# 1                                          6.0
# 2                                          6.0
# 3                                          6.0
# 4                                          6.0
#
#    merchant_merge_hist_avg_sales_lag12_sum  \
# 0                               159.190002
# 1                               334.239990
# 2                                87.479996
# 3                               409.510010
# 4                               559.219971
#
#    merchant_merge_hist_avg_sales_lag12_mean  \
# 0                                  1.068389
# 1                                  2.717398
# 2                                  1.286471
# 3                                  1.844640
# 4                                  3.753154
#
#    merchant_merge_hist_avg_purchases_lag12_sum  \
# 0                                   165.997952
# 1                                   714.115425
# 2                                   105.664009
# 3                                   603.030942
# 4                                  1347.227115
#
#    merchant_merge_hist_avg_purchases_lag12_mean  \
# 0                                      1.114080
# 1                                      5.805816
# 2                                      1.553882
# 3                                      2.716356
# 4                                      9.041793
#
#    merchant_merge_hist_active_months_lag12_sum  \
# 0                                       1776.0
# 1                                       1476.0
# 2                                        806.0
# 3                                       2631.0
# 4                                       1760.0
#
#    merchant_merge_hist_active_months_lag12_mean
# 0                                     11.919463
# 1                                     12.000000
# 2                                     11.852941
# 3                                     11.851351
# 4                                     11.812081
#
# [5 rows x 41 columns]

# %%
df_hist_trans_group.to_pickle('merchant_merge_hist_features.pickle')

# %%
df_hist_trans_group.shape
# Out:
# (325540, 41)

# %%
index=df_hist_trans[~(df_hist_trans.card_id.isin(df_new_merchant_trans['card_id']))].groupby('card_id').count().index

# %%
df_no_new=df_train[df_train.card_id.isin(index)]

# %%
df_no_new[df_no_new.target<-33].shape[0]/df_no_new.shape[0]
# Out:
# 0.026172997127353975

# %%
df_no_new.shape[0]
# Out:
# 21931

# %%
df_no_new_test=df_test[df_test.card_id.isin(index)]

# %%
df_no_new_test.shape[0]
# Out:
# 13608

# %%
13608*0.026172997127353975
# Out:
# 356.16214490903286

# %%
index2=df_hist_trans[~(df_hist_trans.card_id.isin(df_new_merchant_trans['card_id']))].groupby('card_id').count().index

# %%
strange_items = df_hist_trans[~(historical_df['card_id'].isin(new_merchant_df['card_id']))].groupby(['card_id'])['authorized_flag'].agg(['size'])\

                                .reset_index().rename(columns={'size': 'number_of_transactions'})

strange_items = strange_items[strange_items['number_of_transactions']<7]

strange_items = train[(train['card_id'].isin(strange_items['card_id']))&amp;((train['target']<-33)|(train['target']>0))]

# %%
strange_items = df_hist_trans[~(df_hist_trans['card_id'].isin(df_new_merchant_trans['card_id']))].groupby(['card_id'])['authorized_flag'].agg(['size']).reset_index().rename(columns={'size': 'number_of_transactions'})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-fb63e6014aea> in <module>()
# ----> 1 strange_items = df_hist_trans[~(df_hist_trans['card_id'].isin(df_new_merchant_trans['card_id']))].groupby(['card_id'])['authorized_flag'].agg(['size']).reset_index().rename(columns={'size': 'number_of_transactions'})
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     257         else:
#     258             if key not in self.obj:
# --> 259                 raise KeyError("Column not found: {key}".format(key=key))
#     260             return self._gotitem(key, ndim=1)
#     261
#
# KeyError: 'Column not found: authorized_flag'

# %%
df_hist_trans.columns
# Out:
# Index(['card_id', 'merchant_group_id', 'merchant_category_id', 'subsector_id',
#        'numerical_1', 'numerical_2', 'category_1', 'most_recent_sales_range',
#        'most_recent_purchases_range', 'avg_sales_lag3', 'avg_purchases_lag3',
#        'active_months_lag3', 'avg_sales_lag6', 'avg_purchases_lag6',
#        'active_months_lag6', 'avg_sales_lag12', 'avg_purchases_lag12',
#        'active_months_lag12', 'category_4', 'city_id', 'state_id',
#        'category_2'],
#       dtype='object')

# %%
df_hist_trans[~(df_hist_trans['card_id'].isin(df_new_merchant_trans['card_id']))].groupby(['card_id'])['authorized_flag']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-e51b3e7b88c5> in <module>()
# ----> 1 df_hist_trans[~(df_hist_trans['card_id'].isin(df_new_merchant_trans['card_id']))].groupby(['card_id'])['authorized_flag']
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     257         else:
#     258             if key not in self.obj:
# --> 259                 raise KeyError("Column not found: {key}".format(key=key))
#     260             return self._gotitem(key, ndim=1)
#     261
#
# KeyError: 'Column not found: authorized_flag'

# %%
df_hist_trans.head()
# Out:
#            card_id  merchant_group_id  merchant_category_id  subsector_id  \
# 0  C_ID_4e6213e9bc               35.0                  80.0          37.0
# 1  C_ID_4e6213e9bc             2084.0                 367.0          16.0
# 2  C_ID_4e6213e9bc            27369.0                  80.0          37.0
# 3  C_ID_4e6213e9bc            24104.0                 560.0          34.0
# 4  C_ID_4e6213e9bc               35.0                  80.0          37.0
#
#    numerical_1  numerical_2 category_1 most_recent_sales_range  \
# 0    23.468750    23.015625          N                       A
# 1     1.092773    -0.057465          N                       A
# 2     0.021851     0.021851          N                       C
# 3    -0.057465    -0.057465          N                       D
# 4    23.468750    23.015625          N                       A
#
#   most_recent_purchases_range  avg_sales_lag3     ...      avg_sales_lag6  \
# 0                           A            1.08     ...                1.14
# 1                           A            1.06     ...                1.06
# 2                           C            0.98     ...                0.98
# 3                           C            1.00     ...                0.88
# 4                           A            1.08     ...                1.14
#
#    avg_purchases_lag6  active_months_lag6  avg_sales_lag12  \
# 0            1.114135                 6.0             1.19
# 1            1.058605                 6.0             1.05
# 2            0.967058                 6.0             0.97
# 3            0.897406                 6.0             0.86
# 4            1.114135                 6.0             1.19
#
#    avg_purchases_lag12  active_months_lag12  category_4  city_id state_id  \
# 0             1.156844                 12.0           Y     88.0     16.0
# 1             1.062087                 12.0           Y     88.0     16.0
# 2             0.956668                 12.0           Y     88.0     16.0
# 3             0.864394                 12.0           Y     88.0     16.0
# 4             1.156844                 12.0           Y     88.0     16.0
#
#    category_2
# 0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
#
# [5 rows x 22 columns]
