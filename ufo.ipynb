# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib notebook
import seaborn as sns

# %%
ufo=pd.read_csv('http://bit.ly/uforeports')

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.shape
# Out:
# (18241, 5)

# %%
ufo['Shape Reported'].unique()
# Out:
# array(['TRIANGLE', 'OTHER', 'OVAL', 'DISK', 'LIGHT', 'CIRCLE', 'CIGAR',
#        'CYLINDER', 'FIREBALL', 'SPHERE', nan, 'RECTANGLE', 'FORMATION',
#        'FLASH', 'CHEVRON', 'EGG', 'CONE', 'DIAMOND', 'VARIOUS', 'TEARDROP',
#        'CROSS', 'DELTA', 'ROUND', 'DOME', 'PYRAMID', 'CRESCENT', 'FLARE',
#        'HEXAGON'], dtype=object)

# %%
ufo_sorted=ufo.groupby('Shape Reported').count().sort_values('City',ascending=False)
ufo_sorted.head()
# Out:
#                 City  Colors Reported  State  Time
# Shape Reported
# LIGHT           2801              575   2803  2803
# DISK            2119              203   2122  2122
# TRIANGLE        1885              212   1889  1889
# OTHER           1402              183   1402  1402
# CIRCLE          1362              239   1365  1365

# %%
ufo_sorted.index
# Out:
# Index(['LIGHT', 'DISK', 'TRIANGLE', 'OTHER', 'CIRCLE', 'SPHERE', 'FIREBALL',
#        'OVAL', 'CIGAR', 'FORMATION', 'VARIOUS', 'RECTANGLE', 'CYLINDER',
#        'CHEVRON', 'DIAMOND', 'EGG', 'FLASH', 'TEARDROP', 'CONE', 'CROSS',
#        'DELTA', 'ROUND', 'CRESCENT', 'HEXAGON', 'DOME', 'PYRAMID', 'FLARE'],
#       dtype='object', name='Shape Reported')

# %%
plt.figure()
ind=np.arange(len(ufo_sorted.index))
plt.bar(ind, ufo_sorted.City)
plt.xticks(ind,ufo_sorted.index,rotation='vertical')

plt.ylabel('Number of reported observations')
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
ufo_color=ufo.groupby('Colors Reported').count().sort_values('City',ascending=False)

# %%
plt.figure()
ind=np.arange(len(ufo_color.index))
plt.bar(ind, ufo_color.City)
plt.xticks(ind,ufo_color.index,rotation='vertical')
plt.ylabel('Number of reported observations')
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
ufo_state=ufo.groupby('State').count().sort_values('City',ascending=False)

# %%
plt.figure()
ind=np.arange(len(ufo_state.index))
plt.bar(ind, ufo_state.City)
plt.xticks(ind,ufo_state.index,rotation='vertical')
plt.ylabel('Number of reported observations')
plt.xlim(-0.5,20.5)
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
ufo['Time']=pd.to_datetime(ufo['Time'])

# %%
ufo['Time'].dt.year.max()
# Out:
# 2000

# %%
ufo['Time'][1]-ufo['Time'][0]
# Out:
# Timedelta('28 days 22:00:00')

# %%
ufo[ufo['Time'].dt.year==1930].shape[0]
# Out:
# 2

# %%
observed_year=[]
for i in range(ufo['Time'].dt.year.min(),ufo['Time'].dt.year.max()+1):
    observed_year.append(ufo[ufo['Time'].dt.year==i].shape[0])

# %%
year
# Out:
# array([1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940,
#        1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951,
#        1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962,
#        1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973,
#        1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984,
#        1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995,
#        1996, 1997, 1998, 1999], dtype=int64)

# %%
year=np.arange(ufo['Time'].dt.year.min(),ufo['Time'].dt.year.max()+1)
plt.figure()
plt.plot(year,observed_year)
plt.ylabel('Number of reported observation')
plt.xlabel('year')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
observed_hour=[]
for i in range(ufo['Time'].dt.hour.min(),ufo['Time'].dt.hour.max()+1):
    observed_hour.append(ufo[ufo['Time'].dt.hour==i].shape[0])

# %%
hour=np.arange(ufo['Time'].dt.hour.min(),ufo['Time'].dt.hour.max()+1)
plt.figure()
plt.plot(hour,observed_hour)
plt.ylabel('Number of reported observation')
plt.xlabel('hour')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
observed_month=[]
for i in range(ufo['Time'].dt.month.min(),ufo['Time'].dt.month.max()+1):
    observed_month.append(ufo[ufo['Time'].dt.month==i].shape[0])

# %%
month=np.arange(ufo['Time'].dt.month.min(),ufo['Time'].dt.month.max()+1)
plt.figure()
plt.plot(month,observed_month)
plt.ylabel('Number of reported observation')
plt.xlabel('month')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
ufo
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# 5               Valley City             NaN           DISK    ND
# 6               Crater Lake             NaN         CIRCLE    CA
# 7                      Alma             NaN           DISK    MI
# 8                   Eklutna             NaN          CIGAR    AK
# 9                   Hubbard             NaN       CYLINDER    OR
# 10                  Fontana             NaN          LIGHT    CA
# 11                 Waterloo             NaN       FIREBALL    AL
# 12                   Belton             RED         SPHERE    SC
# ...
